# %%
from scipy.ndimage import gaussian_filter1d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import os
import statistics
import scipy.io
import h5py
import sys
PlottingFormat_Folder = '/home/sheffieldlab/Desktop/NoReward/Scripts/PlottingTools/'
sys.path.append(PlottingFormat_Folder)
import plottingfunctions as pf
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Fluoresencetrace_analysis import PlotRaster as r

# %%
ExpDirectoryName = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/'
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/100dpi/'
exptaskstoplot = ['Task1', 'Task2', 'Task3']

# %% [markdown]
# ## CFC4

# %%
d_exp = r(AnimalName='CFC4', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# F (1924, 65000)
# Fc (1924, 65000)
# Fc3 (1924, 65000)
# (1924, 5427) (1924, 39) (5427, 1)
# (1924, 10067) (1924, 61) (10067, 1)
# (1924, 6603) (1924, 37) (6603, 1)
# nmin 200
# 0.07291507720947266
# 2.9614803791046143
# 3.113640785217285
# 3.1176469326019287
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.12s     0        0.0459      2
# 0.14s    10        0.1053      4
# 0.17s    20        0.1498      8
# 0.20s    30        0.2166      18
# 0.22s    40        0.2655      28
# 0.25s    50        0.2680      28
# 0.28s   final      0.2694
# 0.28s upsampled    0.2694
# (1924, 22097)

# %% [markdown]
# ## NR6

# %%
d_exp = r(AnimalName='NR6', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)

# %% [markdown]
# ## NR14

# %%
d_exp = r(AnimalName='NR14', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (378, 6921) (378, 30) (6921, 1)
# (378, 6268) (378, 23) (6268, 1)
# (378, 6856) (378, 20) (6856, 1)
# nmin 200
# 0.013597726821899414
# 1.1191043853759766
# 1.1642036437988281
# 1.1655192375183105
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0460      2
# 0.01s    10        0.1281      4
# 0.03s    20        0.2075      8
# 0.04s    30        0.3184      18
# 0.05s    40        0.4068      28
# 0.07s    50        0.4078      28
# 0.08s   final      0.4078
# 0.08s upsampled    0.4078
# (378, 20045)

# %% [markdown]
# ## NR21

# %%
d_exp = r(AnimalName='NR21', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (304, 7658) (304, 40) (7658, 1)
# (304, 8067) (304, 32) (8067, 1)
# (304, 6620) (304, 22) (6620, 1)
# nmin 200
# 0.012012481689453125
# 1.257580041885376
# 1.3013017177581787
# 1.3023662567138672
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0642      2
# 0.01s    10        0.2147      4
# 0.03s    20        0.3194      8
# 0.04s    30        0.4364      18
# 0.05s    40        0.5236      28
# 0.06s    50        0.5239      28
# 0.07s   final      0.5239
# 0.07s upsampled    0.5239
# (304, 22345)

# %% [markdown]
# ## NR24

# %%
d_exp = r(AnimalName='NR24', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (339, 7352) (339, 27) (7352, 1)
# (339, 5548) (339, 16) (5548, 1)
# (339, 7654) (339, 22) (7654, 1)
# nmin 200
# 0.012177228927612305
# 1.0769662857055664
# 1.1238036155700684
# 1.124925136566162
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0483      2
# 0.01s    10        0.1851      4
# 0.03s    20        0.2554      8
# 0.04s    30        0.3483      18
# 0.05s    40        0.4216      28
# 0.06s    50        0.4225      28
# 0.07s   final      0.4225
# 0.07s upsampled    0.4225
# (339, 20554)

# %% [markdown]
# ## CFC16

# %%
exptaskstoplot = ['Task1', 'Task2']

# %%
d_exp = r(AnimalName='CFC16', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (822, 4961) (822, 31) (4961, 1)
# (822, 5038) (822, 26) (5038, 1)
# nmin 200
# 0.014536619186401367
# 1.0972521305084229
# 1.142369031906128
# 1.1443474292755127
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0312      2
# 0.02s    10        0.1267      4
# 0.03s    20        0.1948      8
# 0.05s    30        0.2843      18
# 0.06s    40        0.3384      28
# 0.08s    50        0.3408      28
# 0.10s   final      0.3433
# 0.10s upsampled    0.3433
# (822, 9999)

# %%
d_exp = r(AnimalName='CFC17', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (358, 8015) (358, 36) (8015, 1)
# (358, 8392) (358, 36) (8392, 1)
# nmin 200
# 0.010813474655151367
# 0.9772288799285889
# 1.0268504619598389
# 1.0281982421875
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0497      2
# 0.02s    10        0.1735      4
# 0.04s    20        0.2544      8
# 0.05s    30        0.3601      18
# 0.08s    40        0.4447      28
# 0.10s    50        0.4469      28
# 0.11s   final      0.4469
# 0.11s upsampled    0.4469
# (358, 16407)

# %% [markdown]
# ## CFC19

# %%
d_exp = r(AnimalName='CFC19', FolderName=ExpDirectoryName,
          SaveFigureFolder=SaveFigureFolder, taskstoplot=exptaskstoplot)
# Out:
# (515, 6820) (515, 36) (6820, 1)
# (515, 3503) (515, 17) (3503, 1)
# nmin 200
# 0.008975982666015625
# 0.9700613021850586
# 1.0210356712341309
# 1.0225679874420166
# (28, 30)
# (60,)
# 1.0
# time; iteration;  explained PC variance
# 0.00s     0        0.0657      2
# 0.03s    10        0.2163      4
# 0.04s    20        0.2913      8
# 0.06s    30        0.3770      18
# 0.07s    40        0.4527      28
# 0.08s    50        0.4551      28
# 0.09s   final      0.4551
# 0.10s upsampled    0.4551
# (515, 10323)
