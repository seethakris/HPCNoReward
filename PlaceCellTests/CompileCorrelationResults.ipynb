# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import scipy.stats
import warnings
import sys

warnings.filterwarnings("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PlottingFormat_Folder = '/home/sheffieldlab/Desktop/NoReward/Scripts/PlottingTools/'
sys.path.append(PlottingFormat_Folder)
import plottingfunctions as pf

# %%
from CompileCorrelation_allanimals import CombineData as cd

# %% [markdown]
# ## Combined correlation

# %%
CombinedFolder = '/home/sheffieldlab/Desktop/NoReward/PlaceFieldCodeTest/ExpAnimals/PlaceCellResults_All/'
ParentDataFolder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused'

x = cd(CombinedFolder, ParentDataFolder)

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='row')
m1, p1, d = x.get_mean_correlation_withshuffle(taskstoplot=['Task1', 'Task2', 'Task2b', 'Task3'], axis=ax)
fs.savefig(os.path.join(CombinedFolder, 'CellCorrelation.pdf'), bbox_inches='tight')
# Out:
# Shuffled laps P-value with lick 0.608, without lick 0.036
# Flattened P-value with lick 0.000000, without lick 0.000000
#       Task1     Task2    Task2b     Task3
# 0  0.663404  0.437768  0.441373       NaN
# 1  0.652885  0.527695  0.246227  0.326173
# 2  0.597369  0.456176  0.114264  0.424710
# 3  0.688279  0.599677  0.344871  0.401753
# 4  0.644829  0.440799  0.406814       NaN
# 5  0.505422  0.484332  0.248550  0.416680
#    Task1     Task2    Task2b     Task3
# 0    1.0  0.659882  0.665316       NaN
# 1    1.0  0.808251  0.377137  0.499587
# 2    1.0  0.763643  0.191279  0.710967
# 3    1.0  0.871269  0.501062  0.583706
# 4    1.0  0.683591  0.630887       NaN
# 5    1.0  0.958273  0.491767  0.824421
# Mean P-value with lick 0.007175, without lick 0.002165

# %%
fs, ax = plt.subplots(1, figsize=(6, 2))
a = x.get_lapwise_correlation_peranimal(taskstoplot=['Task1', 'Task2', 'Task3'], axis=ax)
fs.savefig(os.path.join(CombinedFolder, 'CellCorrelationwithlick.pdf'), bbox_inches='tight')
# Out:
# NR23_placecell_data.npz 0 (6, 30)
# CFC19_placecell_data.npz 0 (6, 30)
# NR6_placecell_data.npz 1 (6, 30)
# CFC16_placecell_data.npz 2 (6, 30)
# CFC4_placecell_data.npz 2 (6, 30)
# NR21_placecell_data.npz 3 (6, 30)
# CFC17_placecell_data.npz 4 (6, 30)
# NR24_placecell_data.npz 5 (6, 30)
# 0 1.0
# 1 0.42333964158244364
# 2 0.3366683676100388
# 3 0.2623316754083572
# 4 0.7487740417065472
# 5 0.054663935891675154
# 6 0.054663935891675154
# 7 0.2001848041775791
# 8 0.14954135458461512
# 9 0.037372988340651475
# 10 0.037372988340651475
# 11 0.010405619868873589
# 12 0.010405619868873589
# 13 0.016309171877754974
# 14 0.024974679293054237
# 15 0.006485307970671367
# 16 0.003947751856903457
# 17 0.010405619868873589
# 18 0.006485307970671367
# 19 0.006485307970671367
# 20 0.006485307970671367
# 21 0.006485307970671367
# 22 0.016309171877754974
# 23 0.024974679293054237
# 24 0.016309171877754974
# 25 0.024974679293054237
# 26 0.016309171877754974
# 27 0.016309171877754974
# ...
