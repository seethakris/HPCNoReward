# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from PlaceCellResults_allanimals import Combinedplots as cp

# %% [markdown]
# ## Experimental Data

# %%
CombinedFolder = '/home/sheffieldlab/Desktop/NoReward/PlaceFieldCodeTest/ExpAnimals/PlaceCellResults_All/'
x = cp(CombinedFolder)

# %% [markdown]
# ### Place cell parameters

# %%
x.plot_pfparams_bytracklength(tasks_to_plot=['Task1', 'Task2b'], nbins=20)

# %%
#All cells
x.plot_pfparams(tasks_to_plot=['Task1', 'Task2b'])
# Out:
# Precision: KStest : p-value 0.0000
# Precision: Wilcoxon : p-value 0.0000
# Precision in Task Task1 against normal distribution p-value 0.0000
# Precision in Task Task2b against normal distribution p-value 0.0000
# Width: KStest : p-value 0.0000
# Width: Wilcoxon : p-value 0.0000
# Width in Task Task1 against normal distribution p-value 0.0000
# Width in Task Task2b against normal distribution p-value 0.0000
# FiringRatio: KStest : p-value 0.0000
# FiringRatio: Wilcoxon : p-value 0.0000
# FiringRatio in Task Task1 against normal distribution p-value 0.0000
# FiringRatio in Task Task2b against normal distribution p-value 0.0000
# Firingintensity: KStest : p-value 0.0000
# Firingintensity: Wilcoxon : p-value 0.0000
# Firingintensity in Task Task1 against normal distribution p-value 0.0000
# Firingintensity in Task Task2b against normal distribution p-value 0.0000
# Stability: KStest : p-value 0.0000
# Stability: Wilcoxon : p-value 0.0000
# ...

# %%
#Common cells
x.plot_pf_params_commoncells(tasks_to_plot=['Task1', 'Task2b'])
# Out:
# Precision: KStest : p-value 0.0000
# Width: KStest : p-value 0.0029
# FiringRatio: KStest : p-value 0.0000
# Firingintensity: KStest : p-value 0.0001
# Stability: KStest : p-value 0.0000

# %% [markdown]
# ### Center of mass heatmap

# %%
x.scatter_of_common_center_of_mass(taskA='Task1', taskB='Task2b')

# %% [markdown]
# ### Center of mass per track length

# %%
y = x.plot_percentpfs_withtrackposition(tasks_to_plot=['Task1', 'Task2b'], bins=5)
# Out:
# Task1 229
# Task2b 285
# Task1 187
# Task2b 112
# Task1 196
# Task2b 188
# Task1 220
# Task2b 67
# Task1 148
# Task2b 111
# Task1 105
# Task2b 80
# Task1 76
# Task2b 48
# Task1 117
# Task2b 66
# Task1 149
# Task2b 119

# %%
x.plot_percentpfs_ofdroppedcells(tasks_to_plot=['Task1', 'Task2b'], bins=5)

# %% [markdown]
# ## Control Data

# %%
CombinedFolder = '/home/sheffieldlab/Desktop/NoReward/PlaceFieldCodeTest/ControlAnimals/PlaceCellResults_All/'
y = cp(CombinedFolder)

# %% [markdown]
# ### Place cell parameters

# %%
#All cells
y.plot_pfparams(tasks_to_plot=['Task1', 'Task1b'])
# Out:
# Precision: KStest : p-value 0.0054
# Precision: Wilcoxon : p-value 0.0034
# Precision in Task Task1 against normal distribution p-value 0.0000
# Precision in Task Task1b against normal distribution p-value 0.0000
# Width: KStest : p-value 0.6900
# Width: Wilcoxon : p-value 0.1810
# Width in Task Task1 against normal distribution p-value 0.0000
# Width in Task Task1b against normal distribution p-value 0.0000
# FiringRatio: KStest : p-value 0.0212
# FiringRatio: Wilcoxon : p-value 0.0293
# FiringRatio in Task Task1 against normal distribution p-value 0.0000
# FiringRatio in Task Task1b against normal distribution p-value 0.0000
# Firingintensity: KStest : p-value 0.2143
# Firingintensity: Wilcoxon : p-value 0.1222
# Firingintensity in Task Task1 against normal distribution p-value 0.0000
# Firingintensity in Task Task1b against normal distribution p-value 0.0000
# Stability: KStest : p-value 0.0000
# Stability: Wilcoxon : p-value 0.0000
# ...

# %%
#Common cells
y.plot_pf_params_commoncells(tasks_to_plot=['Task1', 'Task1b'])
# Out:
# Precision: KStest : p-value 0.0041
# Width: KStest : p-value 0.2733
# FiringRatio: KStest : p-value 0.0557
# Firingintensity: KStest : p-value 0.4039
# Stability: KStest : p-value 0.0000

# %% [markdown]
# ### Center of mass heatmap

# %%
y.scatter_of_common_center_of_mass(taskA='Task1', taskB='Task1b')

# %% [markdown]
# ### Center of mass per track length

# %%
y.plot_percentpfs_withtrackposition(tasks_to_plot=['Task1', 'Task1b'], bins=5)
# Out:
# Task1 203
# Task1b 207
# Task1 200
# Task1b 221
# Task1 177
# Task1b 214
# Task1 197
# Task1b 241

# %%
y.plot_percentpfs_ofdroppedcells(tasks_to_plot=['Task1', 'Task1b'], bins=5)
