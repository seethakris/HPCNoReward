# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
DataDetailsFolder = '/home/sheffieldlab/Desktop/NoReward/Scripts/AnimalDetails/'
sys.path.append(DataDetailsFolder)
import DataDetails
from GetPlaceCellData import GetData as gd
from GetPlaceCellData import PlottingFunctions as pf

# %% [markdown]
# ## CFC3

# %%
CFC3_info = DataDetails.ControlAnimals('CFC3')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/CFC3/'
a = pf(animalinfo=CFC3_info, FolderName=DirectoryName, controlflag=1)
# Out:
# Task1a : Number of Frames: 15000
# Task1b : Number of Frames: 15000
# Total number of cells: 379
# Task1b
# Task1b : Place cells: 205 PlaceFields: 214
# Task1a
# Task1a : Place cells: 144 PlaceFields: 148

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 15
# Number of cells with place fields in both: 129

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## CFC4

# %%
CFC4_info = DataDetails.ControlAnimals('CFC4')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/CFC4/'
a = pf(animalinfo=CFC4_info, FolderName=DirectoryName, v73_flag=1, controlflag=1)
# Out:
# F (678, 40000)
# Fc (678, 40000)
# Fc3 (678, 40000)
# Total number of cells: 678
# Task1b
# Task1b : Place cells: 240 PlaceFields: 241
# Task1a
# Task1a : Place cells: 194 PlaceFields: 197

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 26
# Number of cells with place fields in both: 168

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## CFC17

# %%
CFC17_info = DataDetails.ControlAnimals('CFC17')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/CFC17/'
a = pf(animalinfo=CFC17_info, FolderName=DirectoryName, v73_flag=0, controlflag=1)
# Out:
# Task1a : Number of Frames: 15000
# Task1b : Number of Frames: 15000
# Total number of cells: 479
# Task1a
# Task1a : Place cells: 188 PlaceFields: 203
# Task1b
# Task1b : Place cells: 187 PlaceFields: 207

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', placecell_flag=1, figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 54
# Number of cells with place fields in both: 134

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## CFC19

# %%
CFC19_info = DataDetails.ControlAnimals('CFC19')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/CFC19/'
a = pf(animalinfo=CFC19_info, FolderName=DirectoryName, v73_flag=0, controlflag=1)
# Out:
# Task1a : Number of Frames: 15000
# Task1b : Number of Frames: 15000
# Total number of cells: 326
# Task1a
# Task1a : Place cells: 184 PlaceFields: 200
# Task1b
# Task1b : Place cells: 197 PlaceFields: 221

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 15
# Number of cells with place fields in both: 169

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## NR31

# %%
NR31_info = DataDetails.ControlAnimals('NR31')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/Dataused/NR31/'
a = pf(animalinfo=NR31_info, FolderName=DirectoryName, controlflag=1)
# Out:
# Task1a : Number of Frames: 10000
# Task1b : Number of Frames: 10000
# Total number of cells: 1025
# Task1b
# Task1b : Place cells: 211 PlaceFields: 221
# Task1a
# Task1a : Place cells: 186 PlaceFields: 193

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 54
# Number of cells with place fields in both: 132

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## NR32

# %%
NR32_info = DataDetails.ControlAnimals('NR32')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/Dataused/NR32/'
a = pf(animalinfo=NR32_info, FolderName=DirectoryName, controlflag=1)
# Out:
# Task1a : Number of Frames: 10000
# Task1b : Number of Frames: 10000
# Total number of cells: 459
# Task1b
# Task1b : Place cells: 113 PlaceFields: 124
# Task1a
# Task1a : Place cells: 121 PlaceFields: 132

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 32
# Number of cells with place fields in both: 89

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)

# %% [markdown]
# ## NR34

# %%
NR34_info = DataDetails.ControlAnimals('NR34')

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/Dataused/NR34/'
a = pf(animalinfo=NR34_info, FolderName=DirectoryName, controlflag=1)
# Out:
# Task1a : Number of Frames: 10000
# Task1b : Number of Frames: 10000
# Total number of cells: 690
# Task1b
# Task1b : Place cells: 195 PlaceFields: 207
# Task1a
# Task1a : Place cells: 169 PlaceFields: 180

# %% [markdown]
# ### Place cell heatmaps

# %%
pcdict, sortedpcs = a.get_and_sort_placeactivity()
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %%
pcdict, sortedpcs = a.calculate_remapping_with_task('Task1a')
a.plot_placecells_with_track_pertask(pcdict, sortedpcs, figsize=(5, 4))

# %% [markdown]
# ### Correlation of place cells

# %%
a.plot_correlation_by_task(a.correlation_per_task, placecell_flag=1, taskA='Task1a', figsize=(6, 6))

# %%
a.plot_correlation_by_task(a.correlation_per_task, taskA='Task1a', figsize=(6, 6))

# %% [markdown]
# ### Place cell numbers

# %%
a.plot_common_PF_heatmap()

# %% [markdown]
# ### Place cell parameters

# %%
a.plot_percent_PFs_bytracklength(tasks_to_plot=['Task1a', 'Task1b'],bins=20)
# Out:
# Number of cells without place fields in Task1b : 15
# Number of cells with place fields in both: 129

# %%
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='bar')
a.plot_pfparams(tasks_to_plot=['Task1a', 'Task1b'], plottype='hist')

# %%
b = a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='bar')
a.plot_pfparams_commoncells(taskA = 'Task1a', taskB ='Task1b', plottype='hist')

# %%
a.plot_pfparams_bytracklength(tasks_to_plot=['Task1a', 'Task1b'], nbins=10)
