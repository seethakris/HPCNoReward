# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Attention import CompileData

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/'
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/100dpi/Attention/'

# %%
d = CompileData(DirectoryName)

# %%
fs, ax = plt.subplots(1, 3, dpi=100, sharex='all', sharey='all')
d.plot_velocity_slope_bytask(data=d.velocity_slope, axis=ax[0], tasktoplot='Task1')
d.plot_velocity_slope_bytask(data=d.velocity_slope_dark, axis=ax[1], title='Dark')
d.plot_velocity_slope_bytask(data=d.velocity_slope, axis=ax[2], tasktoplot='Task2')
ax[0].set_ylabel('Normalized velocity')
fs.set_size_inches((9, 2))

fs.savefig(os.path.join(SaveFigureFolder, 'Velocity_inVRandDark_withnorew.pdf'), bbox_inches='tight', transparent=True)

# %%
fs, ax = plt.subplots(1, dpi=100)
d.plot_histogram_speed_ratio(ax, taskstoplot=['Task1', 'Task2'], bins=30)
fs.set_size_inches((4, 3))
fs.savefig(os.path.join(SaveFigureFolder, 'Histogram_dark_vr_speedratio.pdf'), bbox_inches='tight', transparent=True)

# %%
fs, ax = plt.subplots(1, 3, dpi=100, sharex='all', sharey='all')
d.velocity_inspace_byattention(ax)
fs.set_size_inches((8, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'BehaviorinNorewardCondition.pdf'), bbox_inches='tight', transparent=True)

# %%
#Number of attendded and unattended laps
fs, ax = plt.subplots(1, dpi=100)
d.get_lap_percentage(ax)
# Out:
# CFC17: Laps with attn: 93.548, Laps without attn: 3.226
# NR14: Laps with attn: 86.667, Laps without attn: 6.667
# NR15: Laps with attn: 47.059, Laps without attn: 52.941
# NR23: Laps with attn: 82.143, Laps without attn: 14.286
# CFC4: Laps with attn: 92.000, Laps without attn: 6.000
# NR6: Laps with attn: 93.333, Laps without attn: 6.667
# CFC19: Laps with attn: 81.818, Laps without attn: 9.091
# NR24: Laps with attn: 61.538, Laps without attn: 30.769
# NR21: Laps with attn: 96.296, Laps without attn: 0.000
# CFC16: Laps with attn: 86.957, Laps without attn: 8.696
# Percentage of attentive laps 82.136 +/- 5.002
# Percentage of not attentive laps 13.834 +/- 5.092
