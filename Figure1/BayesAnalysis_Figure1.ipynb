# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from BayesAnalysis import BayesError, GetErrordata, PlotErrorData, GetPValues

# %%
Bayes_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/BayesResults_All/'
Parent_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/'
Lick_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/LickData/'

# %%
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/100dpi/BayesCompiled/'

# %%
er = GetErrordata(Parent_folder, Bayes_folder, Lick_folder)
# Out:
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz

# %% [markdown]
# ## Plot shuffle error with lick stop = 2

# %%
fs, ax = plt.subplots(2, 2, sharex='all', dpi=100)
ax = ax.flatten()
er.plot_shuffleerror_withlickstop(axis=ax, taskstoplot=['Task1', 'Task2', 'Task2b', 'Task3'],
                                  lickstopdf=er.lickstop_df)
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withdefinedlickstops.pdf'), bbox_inches='tight', transparent=True)
# Out:
# P-values for : Lick stops with First0
# Removing ouliers ['NR23', 'NR14', 'NR15']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.125
# Normality test for Task2 p-value 0.161
# Normality test for Task2b p-value 0.550
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.949046  0.863359  0.733849
# CFC4   0.944192  0.828161  0.379521
# NR6    0.972006  0.904998  0.570889
# CFC19  0.947672  0.907146    0.7804
# NR24    0.85806  0.876451  0.569969
# NR21   0.975221  0.913663  0.605178
# CFC16  0.887337  0.901964   0.70671
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.5553 0.0432   0.1295  False
# Task1  Task2b 5.7663 0.0012   0.0036   True
# Task2  Task2b 5.8916 0.0011   0.0032   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.124
# Normality test for Task2 p-value 0.001
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.949046  0.863359  0.733849
# NR14   0.928678  0.641886  0.572103
# NR15   0.931244  0.914149  0.325128
# NR23   0.813537  0.820697  0.682584
# CFC4   0.944192  0.828161  0.379521
# NR6    0.972006  0.904998  0.570889
# CFC19  0.947672  0.907146    0.7804
# NR24    0.85806  0.876451  0.569969
# NR21   0.975221  0.913663  0.605178
# CFC16  0.887337  0.901964   0.70671
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
# Task1  Task2  7.0  0.0367    0.11   False
# Task1  Task2b 0.0  0.0051   0.0152   True
# Task2  Task2b 0.0  0.0051   0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First2
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.183
# Normality test for Task2 p-value 0.266
# Normality test for Task2b p-value 0.247
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948628  0.863371  0.734567
# NR15   0.931416  0.917254  0.334081
# CFC4     0.9442  0.850859   0.36116
# NR6    0.971877  0.857216   0.56991
# CFC19  0.947577  0.903033  0.760247
# NR24   0.858196  0.876451  0.574922
# NR21   0.975257  0.908319  0.555148
# CFC16  0.887566  0.901964  0.710941
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.7168 0.0299   0.0897  False
# Task1  Task2b 5.9596 0.0006   0.0017   True
# Task2  Task2b 5.3981 0.001    0.003    True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.132
# Normality test for Task2 p-value 0.003
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948628  0.863371  0.734567
# NR14    0.92791  0.665475    0.5534
# NR15   0.931416  0.917254  0.334081
# NR23   0.814738  0.820697  0.678883
# CFC4     0.9442  0.850859   0.36116
# NR6    0.971877  0.857216   0.56991
# CFC19  0.947577  0.903033  0.760247
# NR24   0.858196  0.876451  0.574922
# NR21   0.975257  0.908319  0.555148
# CFC16  0.887566  0.901964  0.710941
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
# Task1  Task2  8.0  0.0469   0.1406  False
# Task1  Task2b 0.0  0.0051   0.0152   True
# Task2  Task2b 0.0  0.0051   0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First4
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.186
# Normality test for Task2 p-value 0.151
# Normality test for Task2b p-value 0.123
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948584  0.860751  0.735824
# NR15   0.930901  0.915374  0.314327
# CFC4   0.944776  0.796689  0.307831
# NR6    0.972216  0.854318  0.559919
# CFC19  0.947664  0.902491  0.759825
# NR24   0.858751  0.876451  0.558192
# NR21   0.975259  0.908197  0.557795
# CFC16  0.888017  0.901964  0.718332
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.6343 0.0337   0.1011  False
# Task1  Task2b 5.653  0.0008   0.0023   True
# Task2  Task2b 5.2804 0.0011   0.0034   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.133
# Normality test for Task2 p-value 0.016
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948584  0.860751  0.735824
# NR14   0.928672  0.663166    0.5443
# NR15   0.930901  0.915374  0.314327
# NR23   0.817008  0.820697  0.676439
# CFC4   0.944776  0.796689  0.307831
# NR6    0.972216  0.854318  0.559919
# CFC19  0.947664  0.902491  0.759825
# NR24   0.858751  0.876451  0.558192
# NR21   0.975259  0.908197  0.557795
# CFC16  0.888017  0.901964  0.718332
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
# Task1  Task2  7.0  0.0367    0.11   False
# Task1  Task2b 0.0  0.0051   0.0152   True
# Task2  Task2b 0.0  0.0051   0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First6
# Removing ouliers ['NR23', 'NR14', 'CFC4', 'CFC4']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.300
# Normality test for Task2 p-value 0.199
# Normality test for Task2b p-value 0.253
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948586  0.862988   0.72863
# NR15   0.930699  0.915125  0.319131
# NR6     0.97196  0.861466  0.560671
# CFC19  0.947612  0.900505  0.760147
# NR24   0.858619  0.876451  0.574325
# NR21   0.975307  0.909729  0.551959
# CFC16  0.887187  0.901964  0.711335
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.2296 0.0673   0.2019  False
# Task1  Task2b 5.4787 0.0015   0.0046   True
# Task2  Task2b 4.7554 0.0031   0.0094   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.127
# Normality test for Task2 p-value 0.008
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948586  0.862988   0.72863
# NR14   0.928807  0.667345  0.543705
# NR15   0.930699  0.915125  0.319131
# NR23   0.813298  0.820697  0.683146
# CFC4   0.943986  0.697679  0.284087
# NR6     0.97196  0.861466  0.560671
# CFC19  0.947612  0.900505  0.760147
# NR24   0.858619  0.876451  0.574325
# NR21   0.975307  0.909729  0.551959
# CFC16  0.887187  0.901964  0.711335
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
# Task1  Task2  7.0  0.0367    0.11   False
# Task1  Task2b 0.0  0.0051   0.0152   True
# Task2  Task2b 0.0  0.0051   0.0152   True
# ------------------------------------------

# %% [markdown]
# ## Plot Shuffle error with any licks

# %%
fs, ax = plt.subplots(1, 2, sharey='all', dpi=200, gridspec_kw={'width_ratios':[1.5, 1]})
er.plot_shuffleerror_withanylicks(axis=ax[0], taskstoplot=['Task1', 'Task2', 'Task2b'],
                                  lickthreshold=2)
er.plot_shuffleerror_withanylicks(axis=ax[1], taskstoplot=['Task1', 'Task3'],
                                  lickthreshold=2)
fs.tight_layout()
fs.set_size_inches((6, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withanylicks.pdf'), bbox_inches='tight', transparent=True)
# Out:
# Removing ouliers ['NR23', 'NR15']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.209
# Normality test for Task2 p-value 0.149
# Normality test for Task2b p-value 0.786
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948625  0.795522  0.745059
# NR14   0.928259  0.670295  0.571593
# CFC4   0.944122  0.710069  0.482873
# NR6    0.971871    0.9307  0.636675
# CFC19  0.947551  0.901377  0.780742
# NR24   0.857978  0.871501  0.588775
# NR21   0.975275  0.868229  0.578216
# CFC16   0.88609  0.904194  0.700665
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.689  0.0311   0.0934  False
# Task1  Task2b 7.8109 0.0001   0.0003   True
# Task2  Task2b 5.8259 0.0006   0.0019   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.133
# Normality test for Task2 p-value 0.183
# Normality test for Task2b p-value 0.796
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948625  0.795522  0.745059
# NR14   0.928259  0.670295  0.571593
# NR15   0.930864  0.863333  0.366287
# NR23   0.814946  0.812173  0.676722
# CFC4   0.944122  0.710069  0.482873
# NR6    0.971871    0.9307  0.636675
# CFC19  0.947551  0.901377  0.780742
# NR24   0.857978  0.871501  0.588775
# NR21   0.975275  0.868229  0.578216
# CFC16   0.88609  0.904194  0.700665
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  2.8083 0.0204   0.0613  False
# Task1  Task2b 6.9495 0.0001   0.0002   True
# Task2  Task2b 5.355  0.0005   0.0014   True
# --------------------------------------------
#
#
#
#
# Removing ouliers ['NR23', 'NR21']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.573
# Normality test for Task3 p-value 0.886
# Performing Parametric test
#
#          Task1     Task3
# NR14  0.928204  0.743728
# CFC4  0.945136  0.853096
# NR6   0.972076  0.802839
# NR24  0.857844  0.770741
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.05, alphacBonf=0.050
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task3  5.2429 0.0135   0.0135   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.264
# Normality test for Task3 p-value 0.536
# Performing Parametric test
#
#          Task1     Task3
# NR14  0.928204  0.743728
# NR23  0.814797  0.676894
# CFC4  0.945136  0.853096
# NR6   0.972076  0.802839
# NR24  0.857844  0.770741
# NR21  0.975308  0.528655
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.05, alphacBonf=0.050
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task3  3.4164 0.0189   0.0189   True
# --------------------------------------------

# %%
fs, ax = plt.subplots(1, sharey='all', dpi=100)
er.plot_shuffleerror_withanylicks(axis=ax, taskstoplot=['Task1', 'Task2', 'Task2b', 'Task3'],
                                  lickthreshold=2, removenan=True)
ax.set_ylim((0.35, 1))
fs.set_size_inches((4, 2))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withanylicks_withrewarddata.pdf'), bbox_inches='tight', transparent=True)
# Out:
# Removing ouliers ['NR23', 'NR21']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.572
# Normality test for Task2 p-value 0.408
# Normality test for Task2b p-value 0.302
# Normality test for Task3 p-value 0.784
# Performing Parametric test
#
#          Task1     Task2    Task2b     Task3
# NR14  0.928432  0.668119   0.57261  0.741574
# CFC4  0.943846  0.706041  0.480077  0.862934
# NR6   0.971949  0.929843  0.618315  0.801255
# NR24  0.857767  0.871501  0.602514  0.767762
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.01, alphacBonf=0.008
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
# Task1  Task2  1.9102 0.1521   0.9126  False
# Task1  Task2b 8.3855 0.0036   0.0213   True
# Task1  Task3  4.8567 0.0167    0.1    False
# Task2  Task2b 4.8269 0.0169   0.1017  False
# Task2  Task3  0.0072 0.9947    1.0    False
# Task2b Task3  -4.265 0.0236   0.1419  False
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.269
# Normality test for Task2 p-value 0.503
# Normality test for Task2b p-value 0.838
# Normality test for Task3 p-value 0.725
# Performing Parametric test
#
#          Task1     Task2    Task2b     Task3
# NR14  0.928432  0.668119   0.57261  0.741574
# NR23  0.814893  0.812173   0.67132  0.677035
# CFC4  0.943846  0.706041  0.480077  0.862934
# NR6   0.971949  0.929843  0.618315  0.801255
# NR24  0.857767  0.871501  0.602514  0.767762
# NR21   0.97527  0.868229  0.567327  0.539644
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.01, alphacBonf=0.008
# =============================================
# group1 group2   stat   pval  pval_corr reject
# ---------------------------------------------
# Task1  Task2   2.191   0.08     0.48   False
# Task1  Task2b  7.0604 0.0009   0.0053   True
# Task1  Task3   3.4485 0.0183   0.1096  False
# Task2  Task2b  6.2094 0.0016   0.0095   True
# Task2  Task3   1.1073 0.3186    1.0    False
# Task2b Task3  -2.4367 0.0589   0.3534  False
# ---------------------------------------------

# %% [markdown]
# ## Boxplot across timebins

# %%
fs, ax = plt.subplots(2, 2, sharex='all', dpi=100)
ax = ax.flatten()
er.get_bayeserror_acrosstimebins(
    axis=ax, taskstoplot=['Task1', 'Task2', 'Task3'], lickstopdf=er.lickstop_df, task2_bins=7)
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'BayesAcrosstimebins_withlickstop.pdf'), bbox_inches='tight', transparent=True)
# Out:
# P-values for : Lick stops with First0
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.056
# Normality test for Bin2 p-value 0.122
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.906244  0.416893
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.907056  0.885750
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.913663  0.920626
# CFC4    0.944302  0.826590  0.790014
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Bin0   Bin1  2.6252 0.0342   0.1025  False
#  Bin0   Bin2  3.0924 0.0175   0.0525  False
#  Bin1   Bin2  2.4482 0.0442   0.1327  False
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.001
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.906244  0.416893
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.907056  0.885750
# NR14    0.928428  0.641217  0.732549
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.913663  0.920626
# CFC4    0.944302  0.826590  0.790014
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Bin0   Bin1  7.0  0.0367    0.11   False
#  Bin0   Bin2  0.0  0.0051   0.0152   True
#  Bin1   Bin2  6.0  0.0284   0.0853  False
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First2
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.197
# Normality test for Bin2 p-value 0.097
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.850030  0.737531
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Bin0   Bin1  2.7428 0.0288   0.0864  False
#  Bin0   Bin2  3.9348 0.0056   0.0169   True
#  Bin1   Bin2  3.3328 0.0125   0.0376   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.003
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.850030  0.737531
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Bin0   Bin1  7.0  0.0367    0.11   False
#  Bin0   Bin2  0.0  0.0051   0.0152   True
#  Bin1   Bin2  2.0  0.0093   0.028    True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First4
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.119
# Normality test for Bin2 p-value 0.147
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.797530  0.430733
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Bin0   Bin1  2.6223 0.0343   0.1029  False
#  Bin0   Bin2  4.0405 0.0049   0.0148   True
#  Bin1   Bin2  3.7431 0.0072   0.0217   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.016
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.797530  0.430733
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Bin0   Bin1  7.0  0.0367    0.11   False
#  Bin0   Bin2  0.0  0.0051   0.0152   True
#  Bin1   Bin2  2.0  0.0093   0.028    True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First6
# Removing ouliers ['NR23', 'NR14', 'CFC4']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.290
# Normality test for Bin1 p-value 0.177
# Normality test for Bin2 p-value 0.181
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Bin0   Bin1  2.2118 0.069    0.2069  False
#  Bin0   Bin2  3.4989 0.0128   0.0385   True
#  Bin1   Bin2  3.1294 0.0203   0.061   False
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.009
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.699875  0.234563
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Bin0   Bin1  7.0  0.0367    0.11   False
#  Bin0   Bin2  0.0  0.0051   0.0152   True
#  Bin1   Bin2  2.0  0.0093   0.028    True
# ------------------------------------------

# %% [markdown]
# ## Histogram of bayes error with sliding window

# %%
er2 = GetErrordata(Parent_folder, Bayes_folder, Lick_folder, CFC12flag=1)
# Out:
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz

# %%
fs, ax = plt.subplots(1, 2, dpi=100, sharex='all', gridspec_kw={'width_ratios':[2, 1.5]})
error, licks = er.get_bayeserror_with_slidingwindow(axis=ax, taskstoplot=['Task1', 'Task2'],  totalnumlaps=30, windowsize=6)
fs.set_size_inches((7, 3))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Histogram_of_licks.pdf'), bbox_inches='tight', transparent=True)
# Out:
# (1, 103) (1, 116)

# %%
fs, ax = plt.subplots(1, 1, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax, licks['Task2'], axislabel='Licks')
ax1 = ax.twinx()
PlotErrorData.plot_lick_withtime(ax1,  np.nan_to_num(
    error['Task2']), axislabel='Bayes', axislim=(0.3, 1),  color='r')
fs.set_size_inches((3, 3))
fs.savefig(os.path.join(SaveFigureFolder, 'Lickandbayeswithslidingwindow1.pdf'),
           bbox_inches='tight', transparent=True)

# %%
fs, ax = plt.subplots(1, 1, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax, licks['Task2'], axislabel='Licks')
ax1 = ax.twinx()
PlotErrorData.plot_lick_withtime(ax1,  np.nan_to_num(error['Task2']), axislabel='Bayes', color='r')
fs.set_size_inches((3, 3))
fs.savefig(os.path.join(SaveFigureFolder, 'Lickandbayeswithslidingwindow2.pdf'), bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Pre-licks with time

# %%
er.load_lick_around_reward(taskstoplot=['Task1', 'Task2'])
# Out:
# ['CFC17', 'NR14', 'NR15', 'NR23', 'CFC4', 'NR6', 'CFC19', 'NR24', 'NR21', 'CFC16', 'CFC12']
# Loading.. CFC17
# Loading.. NR14
# Loading.. NR15
# Loading.. NR23
# Loading.. CFC4
# Loading.. NR6
# Loading.. CFC19
# Loading.. NR24
# Loading.. NR21
# Loading.. CFC16
# Loading.. CFC12

# %%
fs, ax = plt.subplots(1, dpi=100)
PlotErrorData.plotlickdataaroundreward(ax, taskstoplot=['Task1', 'Task2'], lick_data=er.lick_data_dict, 
                         colors=er.colors, frames_per_sec=30.98)
fs.set_size_inches((2, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'Prelick_reward.pdf'), bbox_inches='tight', transparent=True)
