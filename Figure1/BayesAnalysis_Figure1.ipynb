# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from BayesAnalysis import BayesError, GetErrordata, PlotErrorData, GetPValues

# %%
Bayes_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/BayesResults_All/'
Parent_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/'
Lick_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/LickData/'

# %%
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/100dpi/BayesCompiled/'

# %%
er = GetErrordata(Parent_folder, Bayes_folder, Lick_folder)
# Out:
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz

# %% [markdown]
# ## Plot shuffle error with lick stop = 2

# %%
fs, ax = plt.subplots(2, 2, sharex='all', dpi=100)
ax = ax.flatten()
er.plot_shuffleerror_withlickstop(axis=ax, taskstoplot=['Task1', 'Task2', 'Task2b', 'Task3'],
                                  lickstopdf=er.lickstop_df)
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withdefinedlickstops.pdf'), bbox_inches='tight', transparent=True)
# Out:
# P-values for : Lick stops with First0
# Removing ouliers ['NR23', 'NR14', 'NR15', 'CFC4']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.189
# Normality test for Task2 p-value 0.161
# Normality test for Task2b p-value 0.113
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948607  0.861505  0.729136
# NR6     0.97199  0.905546  0.579474
# CFC19   0.94773  0.907228  0.793593
# NR24   0.858722  0.876451   0.57981
# NR21   0.975222  0.913663  0.585168
# CFC16  0.887921  0.901964  0.710943
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.0863 0.0913     0.274  False
#  Task1 Task2b 6.3256 0.0015    0.0044   True
#  Task2 Task2b 5.7871 0.0022    0.0065   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.133
# Normality test for Task2 p-value 0.001
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948607  0.861505  0.729136
# NR14   0.928173  0.643336  0.582402
# NR15   0.930972  0.914353  0.318157
# NR23   0.814963  0.820697  0.681971
# CFC4   0.944177   0.82655  0.384169
# NR6     0.97199  0.905546  0.579474
# CFC19   0.94773  0.907228  0.793593
# NR24   0.858722  0.876451   0.57981
# NR21   0.975222  0.913663  0.585168
# CFC16  0.887921  0.901964  0.710943
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Task1  Task2  7.0 0.0367      0.11  False
#  Task1 Task2b  0.0 0.0051    0.0152   True
#  Task2 Task2b  0.0 0.0051    0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First2
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.185
# Normality test for Task2 p-value 0.243
# Normality test for Task2b p-value 0.298
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17   0.94867  0.862739  0.733387
# NR15   0.931617  0.914646  0.323889
# CFC4   0.944538  0.848896  0.357405
# NR6    0.971848  0.860127  0.567317
# CFC19  0.947575  0.902935  0.767181
# NR24   0.857334  0.876451  0.562312
# NR21   0.975185  0.908829  0.550698
# CFC16    0.8901  0.901964  0.709703
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.7866  0.027    0.0811  False
#  Task1 Task2b  5.927 0.0006    0.0018   True
#  Task2 Task2b 5.3585 0.0011    0.0032   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.122
# Normality test for Task2 p-value 0.003
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17   0.94867  0.862739  0.733387
# NR14   0.928334  0.669093   0.53503
# NR15   0.931617  0.914646  0.323889
# NR23   0.814697  0.820697  0.685436
# CFC4   0.944538  0.848896  0.357405
# NR6    0.971848  0.860127  0.567317
# CFC19  0.947575  0.902935  0.767181
# NR24   0.857334  0.876451  0.562312
# NR21   0.975185  0.908829  0.550698
# CFC16    0.8901  0.901964  0.709703
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Task1  Task2  7.0 0.0367      0.11  False
#  Task1 Task2b  0.0 0.0051    0.0152   True
#  Task2 Task2b  0.0 0.0051    0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First4
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.173
# Normality test for Task2 p-value 0.129
# Normality test for Task2b p-value 0.164
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17   0.94861  0.862999   0.73532
# NR15   0.931682  0.914837  0.324783
# CFC4   0.944797  0.798607  0.304706
# NR6    0.971945  0.856879  0.558873
# CFC19  0.947618  0.903675  0.759965
# NR24   0.858987  0.876451  0.572634
# NR21   0.975228  0.907936  0.552151
# CFC16  0.887272  0.901964  0.722187
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.6356 0.0336    0.1009  False
#  Task1 Task2b 5.5997 0.0008    0.0024   True
#  Task2 Task2b 5.3165 0.0011    0.0033   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.125
# Normality test for Task2 p-value 0.017
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17   0.94861  0.862999   0.73532
# NR14   0.928605  0.671644  0.544369
# NR15   0.931682  0.914837  0.324783
# NR23   0.814739  0.820697  0.682602
# CFC4   0.944797  0.798607  0.304706
# NR6    0.971945  0.856879  0.558873
# CFC19  0.947618  0.903675  0.759965
# NR24   0.858987  0.876451  0.572634
# NR21   0.975228  0.907936  0.552151
# CFC16  0.887272  0.901964  0.722187
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Task1  Task2  7.0 0.0367      0.11  False
#  Task1 Task2b  0.0 0.0051    0.0152   True
#  Task2 Task2b  0.0 0.0051    0.0152   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First6
# Removing ouliers ['NR23', 'NR14', 'CFC4', 'CFC4']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.296
# Normality test for Task2 p-value 0.248
# Normality test for Task2b p-value 0.225
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948744  0.860725  0.735008
# NR15   0.931184   0.91602  0.325581
# NR6    0.972032  0.853735  0.563477
# CFC19  0.947696  0.903242  0.760556
# NR24   0.857998  0.876451  0.562814
# NR21   0.975284  0.908545   0.55412
# CFC16    0.8879  0.901964  0.713477
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.1922 0.0709    0.2126  False
#  Task1 Task2b  5.516 0.0015    0.0045   True
#  Task2 Task2b 4.7335 0.0032    0.0096   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.136
# Normality test for Task2 p-value 0.009
# Performing Non Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948744  0.860725  0.735008
# NR14    0.92845  0.670385  0.545755
# NR15   0.931184   0.91602  0.325581
# NR23   0.816832  0.820697  0.681806
# CFC4   0.943846  0.692912  0.285025
# NR6    0.972032  0.853735  0.563477
# CFC19  0.947696  0.903242  0.760556
# NR24   0.857998  0.876451  0.562814
# NR21   0.975284  0.908545   0.55412
# CFC16    0.8879  0.901964  0.713477
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#  Task1  Task2  7.0 0.0367      0.11  False
#  Task1 Task2b  0.0 0.0051    0.0152   True
#  Task2 Task2b  0.0 0.0051    0.0152   True
# ------------------------------------------

# %% [markdown]
# ## Plot Shuffle error with any licks

# %%
fs, ax = plt.subplots(1, 2, sharey='all', dpi=200, gridspec_kw={'width_ratios':[1.5, 1]})
er.plot_shuffleerror_withanylicks(axis=ax[0], taskstoplot=['Task1', 'Task2', 'Task2b'],
                                  lickthreshold=2)
er.plot_shuffleerror_withanylicks(axis=ax[1], taskstoplot=['Task1', 'Task3'],
                                  lickthreshold=2)
fs.tight_layout()
fs.set_size_inches((6, 2))
# fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withanylicks.pdf'), bbox_inches='tight', transparent=True)
# Out:
# Removing ouliers ['NR23']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.242
# Normality test for Task2 p-value 0.082
# Normality test for Task2b p-value 0.858
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948719  0.794508  0.745932
# NR14    0.92848  0.675856  0.563899
# NR15   0.931465  0.866074  0.379406
# CFC4   0.943219  0.708715  0.482503
# NR6    0.972034  0.930173  0.630506
# CFC19  0.947484  0.900821  0.774658
# NR24   0.857638  0.871501  0.601189
# NR21   0.975234  0.868229  0.576237
# CFC16  0.888598  0.904194  0.705017
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.9456 0.0185    0.0556  False
#  Task1 Task2b 7.3898 0.0001    0.0002   True
#  Task2 Task2b  5.292 0.0007    0.0022   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.129
# Normality test for Task2 p-value 0.166
# Normality test for Task2b p-value 0.856
# Performing Parametric test
#
#           Task1     Task2    Task2b
# CFC17  0.948719  0.794508  0.745932
# NR14    0.92848  0.675856  0.563899
# NR15   0.931465  0.866074  0.379406
# NR23   0.814274  0.812173  0.672749
# CFC4   0.943219  0.708715  0.482503
# NR6    0.972034  0.930173  0.630506
# CFC19  0.947484  0.900821  0.774658
# NR24   0.857638  0.871501  0.601189
# NR21   0.975234  0.868229  0.576237
# CFC16  0.888598  0.904194  0.705017
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task2 2.8279 0.0198    0.0594  False
#  Task1 Task2b 7.0612 0.0001    0.0002   True
#  Task2 Task2b 5.5389 0.0004    0.0011   True
# --------------------------------------------
#
#
#
#
# Removing ouliers ['NR23']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.256
# Normality test for Task3 p-value 0.247
# Performing Parametric test
#
#          Task1     Task3
# NR14  0.928146  0.744209
# CFC4  0.944222  0.860006
# NR6   0.971975  0.802987
# NR24  0.858769   0.77162
# NR21  0.975265  0.537024
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.05, alphacBonf=0.050
# ===========================================
# group1 group2  stat   pval pval_corr reject
# -------------------------------------------
#  Task1  Task3 2.9733 0.041     0.041   True
# -------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.274
# Normality test for Task3 p-value 0.659
# Performing Parametric test
#
#          Task1     Task3
# NR14  0.928146  0.744209
# NR23  0.813576  0.674391
# CFC4  0.944222  0.860006
# NR6   0.971975  0.802987
# NR24  0.858769   0.77162
# NR21  0.975265  0.537024
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.05, alphacBonf=0.050
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#  Task1  Task3 3.4253 0.0187    0.0187   True
# --------------------------------------------

# %%
fs, ax = plt.subplots(1, sharey='all', dpi=100)
er.plot_shuffleerror_withanylicks(axis=ax, taskstoplot=['Task1', 'Task2', 'Task2b', 'Task3'],
                                  lickthreshold=2, removenan=True)
ax.set_ylim((0.35, 1))
fs.set_size_inches((4, 2))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withanylicks_withrewarddata.pdf'), bbox_inches='tight', transparent=True)
# Out:
# Removing ouliers ['NR23', 'NR21']
# Multiple comparisons after removing Outliers
# Normality test for Task1 p-value 0.573
# Normality test for Task2 p-value 0.366
# Normality test for Task2b p-value 0.548
# Normality test for Task3 p-value 0.853
# Performing Parametric test
#
#          Task1     Task2    Task2b     Task3
# NR14   0.92824  0.677969  0.564868  0.742417
# CFC4  0.944265  0.708154  0.475844  0.857618
# NR6   0.971943  0.929816  0.625636  0.803441
# NR24  0.857617  0.871501  0.599868  0.769092
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.01, alphacBonf=0.008
# =============================================
# group1 group2   stat   pval  pval_corr reject
# ---------------------------------------------
#  Task1  Task2  1.9154 0.1513    0.9079  False
#  Task1 Task2b  8.3075 0.0037    0.0219   True
#  Task1  Task3  5.0715 0.0148    0.0888  False
#  Task2 Task2b  5.5177 0.0117    0.0703  False
#  Task2  Task3   0.056 0.9589       1.0  False
# Task2b  Task3 -4.3771 0.0221    0.1324  False
# ---------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.267
# Normality test for Task2 p-value 0.487
# Normality test for Task2b p-value 0.879
# Normality test for Task3 p-value 0.638
# Performing Parametric test
#
#          Task1     Task2    Task2b     Task3
# NR14   0.92824  0.677969  0.564868  0.742417
# NR23  0.815359  0.812173  0.675146  0.673385
# CFC4  0.944265  0.708154  0.475844  0.857618
# NR6   0.971943  0.929816  0.625636  0.803441
# NR24  0.857617  0.871501  0.599868  0.769092
# NR21  0.975241  0.868229  0.565318  0.532653
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.01, alphacBonf=0.008
# =============================================
# group1 group2   stat   pval  pval_corr reject
# ---------------------------------------------
#  Task1  Task2  2.2078 0.0783    0.4699  False
#  Task1 Task2b  6.9441  0.001    0.0057   True
#  Task1  Task3   3.439 0.0185    0.1107  False
#  Task2 Task2b  6.6601 0.0012    0.0069   True
#  Task2  Task3  1.1731 0.2936       1.0  False
# Task2b  Task3 -2.3796 0.0632    0.3792  False
# ---------------------------------------------

# %% [markdown]
# ## Boxplot across timebins

# %%
fs, ax = plt.subplots(2, 2, sharex='all', dpi=100)
ax = ax.flatten()
er.get_bayeserror_acrosstimebins(
    axis=ax, taskstoplot=['Task1', 'Task2', 'Task3'], lickstopdf=er.lickstop_df, task2_bins=7)
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'BayesAcrosstimebins_withlickstop.pdf'), bbox_inches='tight', transparent=True)
# Out:
# P-values for : Lick stops with First0
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.056
# Normality test for Bin2 p-value 0.122
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.906244  0.416893
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.907056  0.885750
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.913663  0.920626
# CFC4    0.944302  0.826590  0.790014
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#   Bin0   Bin1 2.6252 0.0342    0.1025  False
#   Bin0   Bin2 3.0924 0.0175    0.0525  False
#   Bin1   Bin2 2.4482 0.0442    0.1327  False
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.001
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.906244  0.416893
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.907056  0.885750
# NR14    0.928428  0.641217  0.732549
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.913663  0.920626
# CFC4    0.944302  0.826590  0.790014
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#   Bin0   Bin1  7.0 0.0367      0.11  False
#   Bin0   Bin2  0.0 0.0051    0.0152   True
#   Bin1   Bin2  6.0 0.0284    0.0853  False
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First2
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.197
# Normality test for Bin2 p-value 0.097
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.850030  0.737531
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#   Bin0   Bin1 2.7428 0.0288    0.0864  False
#   Bin0   Bin2 3.9348 0.0056    0.0169   True
#   Bin1   Bin2 3.3328 0.0125    0.0376   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.003
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.850030  0.737531
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#   Bin0   Bin1  7.0 0.0367      0.11  False
#   Bin0   Bin2  0.0 0.0051    0.0152   True
#   Bin1   Bin2  2.0 0.0093     0.028   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First4
# Removing ouliers ['NR23', 'NR14']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.181
# Normality test for Bin1 p-value 0.119
# Normality test for Bin2 p-value 0.147
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.797530  0.430733
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#   Bin0   Bin1 2.6223 0.0343    0.1029  False
#   Bin0   Bin2 4.0405 0.0049    0.0148   True
#   Bin1   Bin2 3.7431 0.0072    0.0217   True
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.016
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.797530  0.430733
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#   Bin0   Bin1  7.0 0.0367      0.11  False
#   Bin0   Bin2  0.0 0.0051    0.0152   True
#   Bin1   Bin2  2.0 0.0093     0.028   True
# ------------------------------------------
#
#
#
#
# P-values for : Lick stops with First6
# Removing ouliers ['NR23', 'NR14', 'CFC4']
# Multiple comparisons after removing Outliers
# Normality test for Bin0 p-value 0.290
# Normality test for Bin1 p-value 0.177
# Normality test for Bin2 p-value 0.181
# Performing Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ============================================
# group1 group2  stat   pval  pval_corr reject
# --------------------------------------------
#   Bin0   Bin1 2.2118  0.069    0.2069  False
#   Bin0   Bin2 3.4989 0.0128    0.0385   True
#   Bin1   Bin2 3.1294 0.0203     0.061  False
# --------------------------------------------
#
#
#
#
# Multiple comparisons without removing outliers
# Normality test for Bin0 p-value 0.128
# Normality test for Bin1 p-value 0.009
# Performing Non Parametric test
#
#             Bin0      Bin1      Bin2
# Animal
# NR6     0.972000  0.858036  0.480647
# CFC17   0.948636  0.861959  0.736994
# NR15    0.931262  0.914647  0.391868
# CFC19   0.947646  0.903151  0.857119
# NR14    0.928428  0.669250  0.729089
# NR24    0.858349  0.876451  0.809079
# CFC16   0.887245  0.901964  0.700001
# NR21    0.975241  0.909406  0.785295
# CFC4    0.944302  0.699875  0.234563
# NR23    0.814606  0.820697  0.516380
# Test Multiple Comparison wilcoxon
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ==========================================
# group1 group2 stat  pval  pval_corr reject
# ------------------------------------------
#   Bin0   Bin1  7.0 0.0367      0.11  False
#   Bin0   Bin2  0.0 0.0051    0.0152   True
#   Bin1   Bin2  2.0 0.0093     0.028   True
# ------------------------------------------

# %% [markdown]
# ## Histogram of bayes error with sliding window

# %%
#Remove laps that dont have attention
fs, ax = plt.subplots(1, 2, dpi=100, sharex='all', gridspec_kw={'width_ratios':[2, 1.5]})
error, licks = er.get_bayeserror_with_slidingwindow(axis=ax, taskstoplot=['Task1', 'Task2'],  totalnumlaps=30, windowsize=6)
fs.set_size_inches((7, 3))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Histogram_of_licks.pdf'), bbox_inches='tight', transparent=True)
# Out:
# (1, 103) (1, 116)

# %%
fs, ax = plt.subplots(1, 1, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax, licks['Task2'], axislabel='Licks')
ax1 = ax.twinx()
PlotErrorData.plot_lick_withtime(ax1,error['Task2'], axislabel='Bayes', axislim=(0.3, 1),  color='r')
fs.set_size_inches((3, 3))
fs.savefig(os.path.join(SaveFigureFolder, 'Lickandbayeswithslidingwindow1.pdf'),
           bbox_inches='tight', transparent=True)

# %%
fs, ax = plt.subplots(1, 1, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax, licks['Task2'], axislabel='Licks')
ax1 = ax.twinx()
PlotErrorData.plot_lick_withtime(ax1,
    error['Task2'], axislabel='Bayes', color='r')
fs.set_size_inches((3, 3))
fs.savefig(os.path.join(SaveFigureFolder, 'Lickandbayeswithslidingwindow2.pdf'),
           bbox_inches='tight', transparent=True)

# %%
e, l, v = er.get_bayeserror_with_slidingwindow_withvelocity(taskstoplot=['Task1', 'Task2'],  totalnumlaps=30, windowsize=6)
# Out:
# NR6 (39,)
# NR6 (22,)
# CFC17 (35,)
# CFC17 (35,)
# NR15 (33,)
# NR15 (26,)
# CFC19 (35,)
# CFC19 (16,)
# NR14 (29,)
# NR14 (22,)
# NR24 (26,)
# NR24 (15,)
# CFC16 (30,)
# CFC16 (25,)
# NR21 (39,)
# NR21 (31,)
# CFC4 (38,)
# CFC4 (60,)
# NR23 (39,)
# NR23 (32,)

# %%
fs, ax = plt.subplots(1, 1, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax, l['Task2'], axislabel='Licks')
ax1 = ax.twinx()
PlotErrorData.plot_lick_withtime(ax1,
    e['Task2'],  axislabel='Bayes', color='r', dashed=1)
PlotErrorData.fit_error_with_sigmoid(ax1, e['Task2'])
PlotErrorData.plot_lick_withtime(
    ax1, v['Task2'],  axislabel='Bayes', color='green')
fs.set_size_inches((3, 3))
# Out:
# Critical Point 9
# R-squared 0.94

# %% [markdown]
# ## Different ways of plotting error and fit

# %%
fs, ax = plt.subplots(1, 2, dpi=100, sharex='all')

#With errobars
PlotErrorData.plot_lick_withtime(ax[0], 
    e['Task2'],  axislim=(0.35, 1), axislabel='Bayes', color='r', errorbar=1, dashed=0)
PlotErrorData.fit_error_with_sigmoid(ax[0], e['Task2'])


#without errorbars
PlotErrorData.plot_lick_withtime(ax[1], 
    e['Task2'],  axislim=(0.35, 1), axislabel='Bayes', color='r', errorbar=0, dashed=0)
PlotErrorData.fit_error_with_sigmoid(ax[1], e['Task2'])

fs.set_size_inches((6, 3))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_with_boltzmannfit.pdf'),
           bbox_inches='tight', transparent=True)
# Out:
# Critical Point 9
# R-squared 0.94
# Critical Point 9
# R-squared 0.94

# %%
fs, ax = plt.subplots(1, 2, dpi=100, sharex='all')
PlotErrorData.plot_lick_withtime(ax[0], l['Task2'], axislabel='Licks', errorbar=1)
ax1 = ax[0].twinx()
PlotErrorData.plot_lick_withtime(ax1, 
    e['Task2'],  axislim=(0.35, 1), axislabel='Bayes', color='r', errorbar=1, dashed=1)

PlotErrorData.plot_lick_withtime(ax[1], l['Task2'], axislabel='Licks', errorbar=0)
ax1 = ax[1].twinx()
PlotErrorData.plot_lick_withtime(ax1, 
    e['Task2'],  axislim=(0.35, 1), axislabel='Bayes', color='r', errorbar=0, dashed=1)
fs.set_size_inches((7, 3))
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_with_licks_slidingwindow.pdf'),
           bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Pre-licks with time

# %%
er.load_lick_around_reward(taskstoplot=['Task1', 'Task2'])
# Out:
# ['CFC17', 'NR14', 'NR15', 'NR23', 'CFC4', 'NR6', 'CFC19', 'NR24', 'NR21', 'CFC16', 'SaveAnalysed.npz']
# Loading.. CFC17
# Loading.. NR14
# Loading.. NR15
# Loading.. NR23
# Loading.. CFC4
# Loading.. NR6
# Loading.. CFC19
# Loading.. NR24
# Loading.. NR21
# Loading.. CFC16
# Loading.. SaveAnalysed.npz
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-74-50b2090797f3> in <module>
# ----> 1 er.load_lick_around_reward(taskstoplot=['Task1', 'Task2'])
#
# ~/Desktop/NoReward/Scripts/Figure1/BayesAnalysis.py in load_lick_around_reward(self, taskstoplot)
#      62             print('Loading..', i)
#      63             data = np.load(os.path.join(self.ParentDataFolder, i, 'SaveAnalysed', 'behavior_data.npz'),
# ---> 64                            allow_pickle=True)
#      65             for t in taskstoplot:
#      66                 licks = data['licks_bytimefromreward'].item()[t]
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# NotADirectoryError: [Errno 20] Not a directory: '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/SaveAnalysed.npz/SaveAnalysed/behavior_data.npz'

# %%
fs, ax = plt.subplots(1, dpi=100)
PlotErrorData.plotlickdataaroundreward(ax, taskstoplot=['Task1', 'Task2'], lick_data=er.lick_data_dict, 
                         colors=er.colors, frames_per_sec=30.98)
fs.set_size_inches((2, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'Prelick_reward.pdf'), bbox_inches='tight', transparent=True)

# %% [markdown]
# ## Bayes analysis with tracklength

# %%
er = GetErrordata(Parent_folder, Bayes_folder, Lick_folder, CFC12flag=0)

# %%
fs, ax = plt.subplots(1, dpi=100)
x = er.get_bayes_error_withtracklength(ax, taskstoplot=['Task1', 'Task2'])
fs.set_size_inches((4, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'BayesReward_bytracklength.pdf'), bbox_inches='tight', transparent=True)
