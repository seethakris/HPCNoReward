# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from BayesAnalysis_withattention import BayesError, GetErrordata, PlotErrorData

# %%
Bayes_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/BayesResults_All/'
Parent_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/'
Lick_folder = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/Dataused/LickData/'

# %%
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/100dpi/Attention/'

# %%
er = GetErrordata(Parent_folder, Bayes_folder, Lick_folder)
# Out:
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz
# NR6_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# NR15_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR14_decoderfit_with_cntrl_Bayes.npz
# NR24_decoderfit_with_cntrl_Bayes.npz
# CFC12_decoderfit_with_cntrl_Bayes.npz
# CFC16_decoderfit_with_cntrl_Bayes.npz
# NR21_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# NR23_decoderfit_with_cntrl_Bayes.npz

# %% [markdown]
# ## Plot Shuffle error with any licks

# %%
fs, ax = plt.subplots(1, 1, sharey='all', dpi=100)
er.plot_shuffleerror_withanylicks(axis=ax, taskstoplot=['Task1', 'Task2', 'Attended'],
                                  lickthreshold=2)
fs.tight_layout()
fs.set_size_inches((5, 2))
fs.savefig(os.path.join(SaveFigureFolder, 'Bayes_withanylicks.pdf'), bbox_inches='tight', transparent=True)
# Out:
# Removing ouliers []
# 0
# Multiple comparisons without removing outliers
# Normality test for Task1 p-value 0.138
# Normality test for Task2 p-value 0.166
# Normality test for Attended p-value 0.901
# Performing Parametric test
#
#           Task1     Task2  Attended
# CFC17  0.955045  0.798309  0.750804
# NR14   0.924716  0.670965  0.621652
# NR15   0.933092  0.865678  0.826142
# NR23   0.806614  0.812173  0.716037
# CFC4   0.928108  0.710536  0.461239
# NR6     0.97198  0.930515  0.646667
# CFC19  0.936974  0.899983  0.875953
# NR24   0.846501  0.871501  0.781104
# NR21   0.969088  0.868229  0.541518
# CFC16   0.87232  0.904194  0.728024
# Test Multiple Comparison ttest_rel
# FWER=0.05 method=Bonf
# alphacSidak=0.02, alphacBonf=0.017
# ===============================================
#  group1  group2   stat   pval  pval_corr reject
# -----------------------------------------------
# Attended  Task1 -4.5808 0.0013     0.004   True
# Attended  Task2 -3.8946 0.0036    0.0109   True
#    Task1  Task2  2.5721 0.0301    0.0903  False
# -----------------------------------------------
