# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import scipy.stats
import warnings
import sys

warnings.filterwarnings("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
DataDetailsFolder = '/home/sheffieldlab/Desktop/NoReward/Scripts/AnimalDetails/'
sys.path.append(DataDetailsFolder)
import DataDetails
from bayes_withoutrewzones import runSVM
from get_data_for_bayes import SVMValidationPlots

# %%
task_dict = {'Task1':'1 Fam Rew', 
             'Task2':'2 No Rew', 
             'Task3':'3 Fam Rew', 
             'Task4':'4 Nov Rew'}

# %% [markdown]
# ## NR6

# %%
NR6_info = DataDetails.ExpAnimalDetails('NR6')
data_NR6 = runSVM(animalinfo=NR6_info)
# Out:
# bla
# Removing end zones
# Loading Data
# (12298, 1)
# (10058, 1)
# (7072, 1)
# (11044, 1)
# 2298
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 4780
# Good Running Data Frames after endzone deleted: Task2, 3590
# Good Running Data Frames after endzone deleted: Task3, 2820
# Good Running Data Frames after endzone deleted: Task4, 5030
# Data shapes: (4302, 316) (478, 316) (4302,) (478,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.40%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-438cf3b0be1f> in <module>
#       1 NR6_info = DataDetails.ExpAnimalDetails('NR6')
# ----> 2 data_NR6 = runSVM(animalinfo=NR6_info)
#
# ~/Desktop/NoReward/Scripts/BayesDecoder/Bayes_for_paper/bayes_withoutrewzones.py in runSVM(animalinfo)
#      71     for t in animalinfo['task_dict'].keys():
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR6,
                                                      taskdict=NR6_info['task_dict'],
                                                      taskcolors=NR6_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR6,
                                                         tracklength=NR6_info['tracklength'],
                                                         trackbins=NR6_info['trackbins'],
                                                         taskcolors=NR6_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR14

# %%
NR14_info = DataDetails.ExpAnimalDetails('NR14')
data_NR14 = runSVM(animalinfo=NR14_info)
# Out:
# Removing end zones
# Loading Data
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 3110
# Good Running Data Frames after endzone deleted: Task2, 2060
# Good Running Data Frames after endzone deleted: Task3, 3080
# Good Running Data Frames after endzone deleted: Task4, 3340
# Data shapes: (2799, 378) (311, 378) (2799,) (311,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.35%
# Performing 10-fold validation
# Validation 1
# (2799, 378) (2799,) (311, 378) (311,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.15%
# CV shape (311,)
# Validation 2
# (2799, 378) (2799,) (311, 378) (311,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.30%
# CV shape (311,)
# Validation 3
# (2799, 378) (2799,) (311, 378) (311,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.36%
# CV shape (311,)
# Validation 4
# (2799, 378) (2799,) (311, 378) (311,)
# Fitting Bayes
# Elapsed time 0 seconds
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR14,
                                                      taskdict=NR14_info['task_dict'],
                                                      taskcolors=NR14_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR14,
                                                         tracklength=NR14_info['tracklength'],
                                                         trackbins=NR14_info['trackbins'],
                                                         taskcolors=NR14_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR21

# %%
NR21_info = DataDetails.ExpAnimalDetails('NR21')
data_NR21 = runSVM(animalinfo=NR21_info)
# Out:
# Removing end zones
# Loading Data
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 2890
# Good Running Data Frames after endzone deleted: Task2, 3440
# Good Running Data Frames after endzone deleted: Task3, 2770
# Good Running Data Frames after endzone deleted: Task4, 3180
# Data shapes: (2601, 304) (289, 304) (2601,) (289,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.28%
# Performing 10-fold validation
# Validation 1
# (2601, 304) (2601,) (289, 304) (289,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.29%
# CV shape (289,)
# Validation 2
# (2601, 304) (2601,) (289, 304) (289,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.21%
# CV shape (289,)
# Validation 3
# (2601, 304) (2601,) (289, 304) (289,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.20%
# CV shape (289,)
# Validation 4
# (2601, 304) (2601,) (289, 304) (289,)
# Fitting Bayes
# Elapsed time 0 seconds
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR21,
                                                      taskdict=NR21_info['task_dict'],
                                                      taskcolors=NR21_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR21,
                                                         tracklength=NR21_info['tracklength'],
                                                         trackbins=NR21_info['trackbins'],
                                                         taskcolors=NR21_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR23

# %%
NR23_info = DataDetails.ExpAnimalDetails('NR23')
data_NR23 = runSVM(animalinfo=NR23_info)
# Out:
# Removing end zones
# Loading Data
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 3070
# Good Running Data Frames after endzone deleted: Task2, 2790
# Good Running Data Frames after endzone deleted: Task3, 3330
# Good Running Data Frames after endzone deleted: Task4, 3970
# Data shapes: (2763, 379) (307, 379) (2763,) (307,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.35%
# Performing 10-fold validation
# Validation 1
# (2763, 379) (2763,) (307, 379) (307,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.14%
# CV shape (307,)
# Validation 2
# (2763, 379) (2763,) (307, 379) (307,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.24%
# CV shape (307,)
# Validation 3
# (2763, 379) (2763,) (307, 379) (307,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.38%
# CV shape (307,)
# Validation 4
# (2763, 379) (2763,) (307, 379) (307,)
# Fitting Bayes
# Elapsed time 0 seconds
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR23,
                                                      taskdict=NR23_info['task_dict'],
                                                      taskcolors=NR23_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR23,
                                                         tracklength=NR23_info['tracklength'],
                                                         trackbins=NR23_info['trackbins'],
                                                         taskcolors=NR23_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR24

# %%
NR24_info = DataDetails.ExpAnimalDetails('NR24')
data_NR24 = runSVM(animalinfo=NR24_info)
# Out:
# Removing end zones
# Loading Data
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 3360
# Good Running Data Frames after endzone deleted: Task2, 2160
# Good Running Data Frames after endzone deleted: Task3, 3430
# Good Running Data Frames after endzone deleted: Task4, 4090
# Data shapes: (3024, 339) (336, 339) (3024,) (336,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.31%
# Performing 10-fold validation
# Validation 1
# (3024, 339) (3024,) (336, 339) (336,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.15%
# CV shape (336,)
# Validation 2
# (3024, 339) (3024,) (336, 339) (336,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.17%
# CV shape (336,)
# Validation 3
# (3024, 339) (3024,) (336, 339) (336,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.26%
# CV shape (336,)
# Validation 4
# (3024, 339) (3024,) (336, 339) (336,)
# Fitting Bayes
# Elapsed time 0 seconds
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR24,
                                                      taskdict=NR24_info['task_dict'],
                                                      taskcolors=NR24_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR24,
                                                         tracklength=NR24_info['tracklength'],
                                                         trackbins=NR24_info['trackbins'],
                                                         taskcolors=NR24_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## CFC4

# %%
CFC4_info = DataDetails.ExpAnimalDetails('CFC4')
data_CFC4 = runSVM(animalinfo=CFC4_info)
# Out:
# Removing end zones
# Loading Data
# F (1924, 65000)
# Fc (1924, 65000)
# Fc3 (1924, 65000)
# Loading Behavior
# Good Running Data Frames after endzone deleted: Task1, 1550
# Good Running Data Frames after endzone deleted: Task2, 3570
# Good Running Data Frames after endzone deleted: Task3, 1930
# Good Running Data Frames after endzone deleted: Task4, 3060
# Data shapes: (1395, 1924) (155, 1924) (1395,) (155,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.19%
# Performing 10-fold validation
# Validation 1
# (1395, 1924) (1395,) (155, 1924) (155,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.06%
# CV shape (155,)
# Validation 2
# (1395, 1924) (1395,) (155, 1924) (155,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.23%
# CV shape (155,)
# Validation 3
# (1395, 1924) (1395,) (155, 1924) (155,)
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.16%
# CV shape (155,)
# Validation 4
# ...

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_CFC4,
                                                      taskdict=CFC4_info['task_dict'],
                                                      taskcolors=CFC4_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_CFC4,
                                                         tracklength=CFC4_info['tracklength'],
                                                         trackbins=CFC4_info['trackbins'],
                                                         taskcolors=CFC4_info['task_colors'])
plt.tight_layout()
