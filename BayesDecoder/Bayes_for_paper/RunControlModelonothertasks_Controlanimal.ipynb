# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import scipy.stats
import warnings
import sys

warnings.filterwarnings("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
DataDetailsFolder = '/home/sheffieldlab/Desktop/NoReward/Scripts/AnimalDetails/'
sys.path.append(DataDetailsFolder)
PlottingFormat_Folder = '/home/sheffieldlab/Desktop/NoReward/Scripts/PlottingTools/'
sys.path.append(PlottingFormat_Folder)
import plottingfunctions as pf
import DataDetails
from RunControlmodelonothertasks_controldata import runmodel, plot_lapwiseaccuracy, plot_lapwiseaccuracy_barplot, plot_lapwiseaccuracy_concatenated
from RunControlmodelonothertasks_controldata import plot_errorcorrelation_with_lapvelocity, save_data_fit_params

# %%
SaveFolder = '/home/sheffieldlab/Desktop/NoReward/ControlData/Dataused/BayesResults_All/'
task_dict = {'Task1a':'1 Fam Rew', 
             'Task1b':'2 Fam Rew'}

# %% [markdown]
# ## CFC3

# %%
CFC3_info = DataDetails.ControlAnimals('CFC3')
fit_CFC3, data_CFC3 = runmodel(animalinfo=CFC3_info)
save_data_fit_params(SaveFolder, CFC3_info['animal'], fit_CFC3, data_CFC3)
# Out:
# Loading Data
# (7485, 1)
# (8196, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.46%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.26%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, CFC3_info, task_dict, fit_CFC3, data_CFC3)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], CFC3_info, ['Task1a', 'Task1b'], fit_CFC3, data_CFC3, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], CFC3_info, ['Task1a', 'Task1b'], fit_CFC3, data_CFC3, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], CFC3_info, task_dict, fit_CFC3, data_CFC3, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], CFC3_info, task_dict, fit_CFC3, data_CFC3, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## CFC4

# %%
CFC4_info = DataDetails.ControlAnimals('CFC4')
fit_CFC4, data_CFC4 = runmodel(animalinfo=CFC4_info)
save_data_fit_params(SaveFolder, CFC4_info['animal'], fit_CFC4, data_CFC4)
# Out:
# Loading Data
# F (678, 40000)
# Fc (678, 40000)
# Fc3 (678, 40000)
# (6533, 1)
# (7203, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.40%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.11%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, CFC4_info, task_dict, fit_CFC4, data_CFC4)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], CFC4_info, ['Task1a', 'Task1b'], fit_CFC4, data_CFC4, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], CFC4_info, ['Task1a', 'Task1b'], fit_CFC4, data_CFC4, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], CFC4_info, task_dict, fit_CFC4, data_CFC4, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], CFC4_info, task_dict, fit_CFC4, data_CFC4, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## CFC17

# %%
CFC17_info = DataDetails.ControlAnimals('CFC17')
fit_CFC17, data_CFC17 = runmodel(animalinfo=CFC17_info)
save_data_fit_params(SaveFolder, CFC17_info['animal'], fit_CFC17, data_CFC17)
# Out:
# Loading Data
# (8185, 1)
# (7121, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.47%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.24%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, CFC17_info, task_dict, fit_CFC17, data_CFC17)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], CFC17_info, ['Task1a', 'Task1b'], fit_CFC17, data_CFC17, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], CFC17_info, ['Task1a', 'Task1b'], fit_CFC17, data_CFC17, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], CFC17_info, task_dict, fit_CFC17, data_CFC17, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], CFC17_info, task_dict, fit_CFC17, data_CFC17, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## CFC19

# %%
CFC19_info = DataDetails.ControlAnimals('CFC19')
fit_CFC19, data_CFC19 = runmodel(animalinfo=CFC19_info)
save_data_fit_params(SaveFolder, CFC19_info['animal'], fit_CFC19, data_CFC19)
# Out:
# Loading Data
# (6731, 1)
# (6523, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.44%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.24%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, CFC19_info, task_dict, fit_CFC19, data_CFC19)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], CFC19_info, ['Task1a', 'Task1b'], fit_CFC19, data_CFC19, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], CFC19_info, ['Task1a', 'Task1b'], fit_CFC19, data_CFC19, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], CFC19_info, task_dict, fit_CFC19, data_CFC19, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], CFC19_info, task_dict, fit_CFC19, data_CFC19, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## NR31

# %%
NR31_info = DataDetails.ControlAnimals('NR31')
fit_NR31, data_NR31 = runmodel(animalinfo=NR31_info)
save_data_fit_params(SaveFolder, NR31_info['animal'], fit_NR31, data_NR31)
# Out:
# Loading Data
# (5476, 1)
# (5773, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.54%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.16%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, NR31_info, task_dict, fit_NR31, data_NR31)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], NR31_info, ['Task1a', 'Task1b'], fit_NR31, data_NR31, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], NR31_info, ['Task1a', 'Task1b'], fit_NR31, data_NR31, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], NR31_info, task_dict, fit_NR31, data_NR31, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], NR31_info, task_dict, fit_NR31, data_NR31, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## NR32

# %%
NR32_info = DataDetails.ControlAnimals('NR32')
fit_NR32, data_NR32 = runmodel(animalinfo=NR32_info)
save_data_fit_params(SaveFolder, NR32_info['animal'], fit_NR32, data_NR32)
# Out:
# Loading Data
# (5385, 1)
# (5325, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.47%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.22%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, NR32_info, task_dict, fit_NR32, data_NR32)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], NR32_info, ['Task1a', 'Task1b'], fit_NR32, data_NR32, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], NR32_info, ['Task1a', 'Task1b'], fit_NR32, data_NR32, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], NR32_info, task_dict, fit_NR32, data_NR32, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], NR32_info, task_dict, fit_NR32, data_NR32, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## NR34

# %%
NR34_info = DataDetails.ControlAnimals('NR34')
fit_NR34, data_NR34 = runmodel(animalinfo=NR34_info)
save_data_fit_params(SaveFolder, NR34_info['animal'], fit_NR34, data_NR34)
# Out:
# Loading Data
# (5505, 1)
# (5474, 1)
# bla
# odict_keys(['Xdata', 'Ydata', 'Task1a', 'Task1b'])
# Fitting Bayes
# Elapsed time 0 seconds
#
# Accuracy of test set:: 0.48%
# Max Bins  39.0
# Trace Limits 0.0 39.0
#
# Accuracy of test set:: 0.20%
# Max Bins  39.0
# Trace Limits 0.0 39.0

# %%
fs, ax = plt.subplots(2, 2, figsize=(10, 6), sharex='all')
plot_lapwiseaccuracy(ax, NR34_info, task_dict, fit_NR34, data_NR34)
fs.tight_layout()
# Out:
# bla

# %%
fs, ax = plt.subplots(2, figsize=(8, 4), sharex='all')
plot_lapwiseaccuracy_concatenated(ax[0], NR34_info, ['Task1a', 'Task1b'], fit_NR34, data_NR34, to_plot='R2')
plot_lapwiseaccuracy_concatenated(ax[1], NR34_info, ['Task1a', 'Task1b'], fit_NR34, data_NR34, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %%
fs, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace':0.5})
plot_lapwiseaccuracy_barplot(ax[0], NR34_info, task_dict, fit_NR34, data_NR34, to_plot='R2')
plot_lapwiseaccuracy_barplot(ax[1], NR34_info, task_dict, fit_NR34, data_NR34, to_plot='accuracy')
fs.tight_layout()
# Out:
# bla
# bla

# %% [markdown]
# ## Compilation Plots

# %%
DirectoryName = '/home/sheffieldlab/Desktop/NoReward/ControlData/Dataused/BayesResults_All/'

# %%
from Compiled_Controlmodelontasks_controldata import plot_meancorrelation_withshuffle, plot_lapwiseerror_withlick
from Compiled_Controlmodelontasks_controldata import plot_histogram_error_bytask
task_dict = {'Task1a':'1 Fam Rew', 
             'Task1b':'2 Fam Rew'}

# %% [markdown]
# ## Boxplot correlation

# %%
SaveFigureFolder = '/home/sheffieldlab/Desktop/NoReward/PaperFigures/Figure1/'

# %%
fs, ax = plt.subplots(2, 2, figsize=(8, 6), sharex='row')
m1 = plot_meancorrelation_withshuffle(ax, DirectoryName, trackbins=5,
                                      taskstoplot=['Task1a', 'Task1b'],
                                     to_plot='R2')
fs.tight_layout()
fs.savefig(os.path.join(SaveFigureFolder, 'DecodingAccuracy_Rsquared_Control.pdf'), bbox_inches='tight')
# Out:
# NR32
# 25
# 22
# NR34
# 26
# 23
# CFC17
# 33
# 27
# CFC19
# 35
# 36
# NR31
# 27
# 29
# CFC3
# 48
# 48
# CFC4
# 45
# 44
# Flattened P-value 0.000000
#      Task1a    Task1b
# 0  0.959094  0.780161
# 1  0.963450  0.884159
# 2  0.888110  0.894937
# 3  0.962673  0.936462
# 4  0.934902  0.877250
# 5  0.983711  0.939447
# 6  0.909708  0.912782
#    Task1a    Task1b
# 0     1.0  0.813435
# 1     1.0  0.917701
# 2     1.0  1.007688
# 3     1.0  0.972773
# 4     1.0  0.938333
# 5     1.0  0.955003
# 6     1.0  1.003379
# Mean P-value with lick 0.065826

# %%
fs, ax = plt.subplots(1, figsize=(6, 2))
c, l = plot_lapwiseerror_withlick(ax, DirectoryName, ['Task1a', 'Task1b'], to_plot='R2')
fs.savefig(os.path.join(SaveFigureFolder, 'DecodingwithlickR-squared_control.pdf'), bbox_inches='tight')
# Out:
# NR32_decoderfit_with_cntrl_Bayes.npz
# NR34_decoderfit_with_cntrl_Bayes.npz
# CFC17_decoderfit_with_cntrl_Bayes.npz
# CFC19_decoderfit_with_cntrl_Bayes.npz
# NR31_decoderfit_with_cntrl_Bayes.npz
# CFC3_decoderfit_with_cntrl_Bayes.npz
# CFC4_decoderfit_with_cntrl_Bayes.npz
# 0 1.0
# 1 0.949059680885933
# 2 0.33790401910300505
# 3 0.5652987983097892
# 4 0.949059680885933
# 5 0.17971249487899976
# 6 0.6547208460185769
# 7 0.22479909925003916
# 8 0.11022304635486535
# 9 0.11022304635486535
# 10 0.025347318677468252
# 11 0.27743910513984715
# 12 0.08453346925711071
# 13 0.06391934147515746
# 14 0.025347318677468252
# 15 0.14171996321059
