# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import scipy.stats
import warnings
import sys

warnings.filterwarnings("ignore")
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
DataDetailsFolder = '/home/sheffieldlab/Desktop/NoReward/Scripts/AnimalDetails/'
sys.path.append(DataDetailsFolder)
import DataDetails
from get_data_for_bayes import runSVM
from get_data_for_bayes import SVMValidationPlots

# %%
task_dict = {'Task1':'1 Fam Rew', 
             'Task2':'2 No Rew', 
             'Task3':'3 Fam Rew', 
             'Task4':'4 Nov Rew'}

# %% [markdown]
# ## NR6

# %%
NR6_info = DataDetails.ExpAnimalDetails('NR6', classifier_type='SVM')
data_NR6 = runSVM(animalinfo=NR6_info, classifier_type='SVM')
# Out:
# Loading Data
# (12298, 1)
# (10058, 1)
# (7072, 1)
# (11044, 1)
# 2298
# Loading Behavior
# Good Running Data Frames: Task1, 11100
# Good Running Data Frames: Task2, 7750
# Good Running Data Frames: Task3, 7070
# Good Running Data Frames: Task4, 11040
# Data shapes: (9990, 316) (1110, 316) (9990,) (1110,)
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Performing 10-fold validation
# Validation 1
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.42%
# CV shape (1110,)
# Validation 2
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# CV shape (1110,)
# Validation 3
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.53%
# CV shape (1110,)
# Validation 4
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# CV shape (1110,)
# Validation 5
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# CV shape (1110,)
# Validation 6
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.63%
# CV shape (1110,)
# Validation 7
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.60%
# CV shape (1110,)
# Validation 8
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.61%
# CV shape (1110,)
# Validation 9
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.58%
# CV shape (1110,)
# Validation 10
# (9990, 316) (9990,) (1110, 316) (1110,)
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.52%
# CV shape (1110,)
# Fitting on 3 neurons
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.04%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.09%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.12%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.10%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.11%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.03%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.04%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.03%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.09%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.05%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.06%
# Fitting on 15 neurons
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.09%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.07%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.13%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.11%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.10%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.14%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.14%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.11%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.17%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.13%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.11%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.13%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.12%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.12%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.16%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.11%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.19%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.15%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.17%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.11%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.12%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.14%
# Validation 1
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.10%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.10%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.09%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.10%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.15%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.13%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.16%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.19%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.15%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.17%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.14%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.14%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.22%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.22%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.22%
# Validation 7
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.24%
# Validation 8
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.13%
# Validation 9
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.18%
# Validation 10
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.16%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.31%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.32%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Fitting on 31 neurons
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.20%
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.30%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.35%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.31%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.32%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.32%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.23%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.22%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 3
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.26%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.28%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.31%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.25%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.25%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.24%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.29%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.32%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.22%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.34%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.31%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.26%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.24%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.25%
# Validation 1
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.23%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.22%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.19%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.24%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.22%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.20%
# Validation 1
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.20%
# Validation 2
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.29%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.22%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.19%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.17%
# Fitting on 63 neurons
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 2
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.45%
# Validation 3
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.41%
# Validation 4
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.44%
# Validation 6
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.47%
# Validation 8
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.29%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.27%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.38%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.35%
# Validation 4
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.35%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.41%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.36%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.34%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.35%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.44%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.42%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.34%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.40%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.50%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.43%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.41%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.39%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.44%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.31%
# Validation 2
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.45%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.40%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.34%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.48%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.43%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.44%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.41%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.35%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.26%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.47%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.43%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.38%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.47%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.51%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.47%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.42%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
# Accuracy of test set:: 0.42%
# Validation 1
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.26%
# Validation 2
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 10
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.24%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.43%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.38%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.47%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.48%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.46%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.43%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.44%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.44%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.32%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.44%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.43%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.48%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.47%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.45%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.46%
# Fitting on 158 neurons
# Validation 1
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.34%
# Validation 2
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.51%
# Validation 3
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.56%
# Validation 6
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.54%
# Validation 7
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.49%
# Validation 8
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 9
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.48%
# Validation 10
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.45%
# Validation 1
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.40%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.60%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.50%
# Validation 4
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.53%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.56%
# Validation 7
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.59%
# Validation 9
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.52%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.47%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.51%
# Validation 3
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.50%
# Validation 4
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.39%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 6
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.53%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.58%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.52%
# Validation 10
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.48%
# Validation 1
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.34%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.52%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.47%
# Validation 4
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.43%
# Validation 5
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.54%
# Validation 6
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.51%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.55%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.55%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.49%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.38%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.52%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.54%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.57%
# Validation 7
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.56%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 9
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.52%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.48%
# Validation 1
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.39%
# Validation 2
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.54%
# Validation 3
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.48%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.42%
# Validation 5
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.55%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.61%
# Validation 7
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.54%
# Validation 9
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.55%
# Validation 10
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.49%
# Validation 1
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.37%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.53%
# Validation 3
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.47%
# Validation 4
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.55%
# Validation 6
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.48%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.55%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.52%
# Validation 10
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.50%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.35%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 3
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 6
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.54%
# Validation 8
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.50%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.50%
# Fitting on 252 neurons
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.38%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.63%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.46%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.58%
# Validation 6
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.60%
# Validation 7
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.57%
# Validation 10
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.55%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.38%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.62%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.44%
# Validation 5
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.58%
# Validation 6
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.63%
# Validation 9
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.60%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.51%
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.41%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.46%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.63%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.57%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.57%
# Validation 10
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.50%
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.39%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.58%
# Validation 6
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.59%
# Validation 9
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.43%
# Validation 2
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.60%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.52%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.59%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.57%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.62%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.57%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.40%
# Validation 2
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.62%
# Validation 3
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.51%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.58%
# Validation 6
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.57%
# Validation 8
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.58%
# Validation 9
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.55%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.43%
# Validation 2
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.62%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.48%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.56%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.61%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.57%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.55%
# Validation 10
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.51%
# Validation 1
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.41%
# Validation 2
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.54%
# Validation 4
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.46%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.61%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.61%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.56%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.55%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.54%
# Fitting on 316 neurons
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.42%
# Validation 2
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 3
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.47%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.63%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.58%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.52%
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# Data shapes: (6975, 316) (775, 316) (6975,) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.34%
# Performing 10-fold validation
# Validation 1
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.32%
# CV shape (775,)
# Validation 2
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.17%
# CV shape (775,)
# Validation 3
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.21%
# CV shape (775,)
# Validation 4
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.27%
# CV shape (775,)
# Validation 5
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.43%
# CV shape (775,)
# Validation 6
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.33%
# CV shape (775,)
# Validation 7
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.39%
# CV shape (775,)
# Validation 8
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.44%
# CV shape (775,)
# Validation 9
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.37%
# CV shape (775,)
# Validation 10
# (6975, 316) (6975,) (775, 316) (775,)
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.34%
# CV shape (775,)
# Fitting on 3 neurons
# Validation 1
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.04%
# Validation 3
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.07%
# Validation 4
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.05%
# ...
#
# Accuracy of test set:: 0.24%
# Validation 1
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 34 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 34 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.30%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.20%
# Validation 1
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.35%
# Validation 8
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.25%
# Validation 1
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.26%
# Validation 4
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.27%
# Validation 5
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.23%
# Validation 6
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 35 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 36 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 34 seconds
#
# Accuracy of test set:: 0.24%
# Validation 1
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.23%
# Validation 6
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.31%
# Validation 8
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 33 seconds
#
# Accuracy of test set:: 0.30%
# Validation 10
# Fitting SVM
# Elapsed time 32 seconds
#
# Accuracy of test set:: 0.23%
# Fitting on 252 neurons
# Validation 1
# Fitting SVM
# Elapsed time 40 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.33%
# Validation 5
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.38%
# Validation 8
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.37%
# Validation 9
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 39 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 40 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.34%
# Validation 5
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.30%
# Validation 6
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.35%
# Validation 8
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.37%
# Validation 9
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.34%
# Validation 10
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.29%
# Validation 1
# Fitting SVM
# Elapsed time 40 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 41 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.31%
# Validation 4
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.35%
# Validation 10
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 39 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 41 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.39%
# Validation 9
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.27%
# Validation 1
# Fitting SVM
# Elapsed time 40 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 41 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.33%
# Validation 4
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.23%
# Validation 7
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.36%
# Validation 10
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 45 seconds
#
# Accuracy of test set:: 0.32%
# Validation 5
# Fitting SVM
# Elapsed time 45 seconds
#
# Accuracy of test set:: 0.30%
# Validation 6
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.24%
# Validation 7
# Fitting SVM
# Elapsed time 45 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 45 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.31%
# Validation 10
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 41 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.39%
# Validation 9
# Fitting SVM
# Elapsed time 44 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 40 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 41 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.34%
# Validation 4
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.31%
# Validation 5
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 43 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 42 seconds
#
# Accuracy of test set:: 0.28%
# Fitting on 316 neurons
# Validation 1
# Fitting SVM
# Elapsed time 48 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 50 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 48 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 50 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 48 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 48 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 50 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 53 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 49 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 50 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 48 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 50 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 52 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 51 seconds
#
# Accuracy of test set:: 0.31%
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR6,
                                                      taskdict=NR6_info['task_dict'],
                                                      taskcolors=NR6_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR6,
                                                         tracklength=NR6_info['tracklength'],
                                                         trackbins=NR6_info['trackbins'],
                                                         taskcolors=NR6_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR14

# %%
NR14_info = DataDetails.ExpAnimalDetails('NR14', classifier_type='SVM')
data_NR14 = runSVM(animalinfo=NR14_info, classifier_type='SVM')
# Out:
# Loading Data
# (6921, 1)
# (6268, 1)
# (6856, 1)
# (7378, 1)
# 1625
# Loading Behavior
# Good Running Data Frames: Task1, 6920
# Good Running Data Frames: Task2, 4640
# Good Running Data Frames: Task3, 6850
# Good Running Data Frames: Task4, 7370
# Data shapes: (6228, 378) (692, 378) (6228,) (692,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.52%
# Performing 10-fold validation
# Validation 1
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# CV shape (692,)
# Validation 2
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# CV shape (692,)
# Validation 3
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# CV shape (692,)
# Validation 4
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# CV shape (692,)
# Validation 5
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# CV shape (692,)
# Validation 6
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.53%
# CV shape (692,)
# Validation 7
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.52%
# CV shape (692,)
# Validation 8
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# CV shape (692,)
# Validation 9
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.51%
# CV shape (692,)
# Validation 10
# (6228, 378) (6228,) (692, 378) (692,)
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.52%
# CV shape (692,)
# Fitting on 3 neurons
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.11%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.02%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.02%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.02%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.02%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.03%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Fitting on 18 neurons
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
# Accuracy of test set:: 0.13%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.13%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.02%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.13%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.23%
# Validation 4
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.16%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.21%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.21%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.17%
# Validation 8
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.15%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.14%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.13%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.13%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.16%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.22%
# Validation 4
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.14%
# Validation 5
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.22%
# Validation 6
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.18%
# Validation 8
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.16%
# Validation 9
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.20%
# Validation 10
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.23%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.20%
# Validation 4
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.12%
# Validation 5
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.19%
# Validation 6
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.18%
# Validation 7
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.17%
# Validation 8
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.15%
# Validation 9
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.17%
# Validation 10
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.15%
# Fitting on 37 neurons
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.11%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.17%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.27%
# Validation 1
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.21%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.10%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.14%
# Validation 6
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.23%
# Validation 7
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.22%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.18%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.18%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.22%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.16%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.13%
# Validation 5
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.19%
# Validation 6
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.21%
# Validation 7
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.16%
# Validation 8
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.18%
# Validation 9
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.18%
# Validation 10
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.18%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.17%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.17%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.27%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.20%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.25%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.16%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.16%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.19%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.16%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.20%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.15%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.23%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.29%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.21%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.22%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.20%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.14%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.16%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.21%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.18%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.17%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.22%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.19%
# Fitting on 75 neurons
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.22%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.22%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.24%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.32%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.35%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.32%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.25%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.35%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.42%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.32%
# Validation 5
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.33%
# Validation 9
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.23%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.24%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.26%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.27%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.25%
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.26%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.21%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.32%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.36%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.20%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.35%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.37%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.28%
# Fitting on 189 neurons
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.44%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.40%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.45%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.45%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.48%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.39%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.42%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.29%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.38%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.42%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.51%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.42%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.53%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.48%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.46%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.40%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.45%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.43%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.47%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.40%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.49%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.47%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.23%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.43%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.32%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.41%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.45%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.38%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.47%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.47%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.38%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.31%
# Validation 5
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.43%
# Validation 6
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.46%
# Validation 7
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.38%
# Validation 8
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.46%
# Validation 10
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.44%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.14%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.29%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.46%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.37%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.41%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.49%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.49%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.46%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.42%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.46%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.47%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.35%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.43%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.46%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.51%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.39%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.44%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.45%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.48%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.45%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.44%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.49%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.49%
# Fitting on 302 neurons
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.48%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.39%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.46%
# Validation 6
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.50%
# Validation 7
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.40%
# Validation 9
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.53%
# Validation 10
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.53%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.29%
# Validation 3
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.46%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.40%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.49%
# Validation 7
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.14%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.50%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.43%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.48%
# Validation 6
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.50%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.46%
# Validation 9
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.52%
# Validation 10
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.48%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.42%
# Validation 5
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.47%
# Validation 6
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.51%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.43%
# Validation 9
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.50%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.47%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.43%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.47%
# Validation 6
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.49%
# Validation 7
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.54%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.54%
# Validation 10
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.54%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.16%
# Validation 2
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.29%
# Validation 3
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.49%
# Validation 6
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.43%
# Validation 9
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.49%
# Validation 1
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.16%
# Validation 2
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.45%
# Validation 6
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.51%
# Validation 7
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.54%
# Validation 8
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.41%
# Validation 9
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.48%
# Validation 10
# Fitting SVM
# Elapsed time 22 seconds
#
# Accuracy of test set:: 0.48%
# Validation 1
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.29%
# Validation 3
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.43%
# Validation 4
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.37%
# Validation 5
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.48%
# Validation 6
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.50%
# Validation 7
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.53%
# Validation 8
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.44%
# Validation 9
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.54%
# Validation 10
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.49%
# Fitting on 378 neurons
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 28 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.49%
# Validation 4
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 5
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.50%
# Validation 6
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.53%
# Validation 7
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# Validation 8
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.51%
# Validation 10
# Fitting SVM
# Elapsed time 27 seconds
#
# Accuracy of test set:: 0.52%
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# Data shapes: (4176, 378) (464, 378) (4176,) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.12%
# Performing 10-fold validation
# Validation 1
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.37%
# CV shape (464,)
# Validation 2
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.38%
# CV shape (464,)
# Validation 3
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.33%
# CV shape (464,)
# Validation 4
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.31%
# CV shape (464,)
# Validation 5
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.30%
# CV shape (464,)
# Validation 6
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.39%
# CV shape (464,)
# Validation 7
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.38%
# CV shape (464,)
# Validation 8
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.25%
# CV shape (464,)
# Validation 9
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.12%
# CV shape (464,)
# Validation 10
# (4176, 378) (4176,) (464, 378) (464,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.12%
# CV shape (464,)
# Fitting on 3 neurons
# Validation 1
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.09%
# Validation 7
# Fitting SVM
# ...
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.14%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.11%
# Validation 3
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.30%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.29%
# Validation 7
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.13%
# Validation 3
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.31%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.22%
# Validation 5
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.35%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.30%
# Validation 10
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.12%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.20%
# Validation 4
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.21%
# Validation 5
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.29%
# Validation 7
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.35%
# Validation 8
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.29%
# Validation 1
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.13%
# Validation 3
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.21%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.18%
# Validation 5
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.34%
# Validation 7
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.32%
# Validation 8
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 19 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.28%
# Fitting on 302 neurons
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.16%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.12%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.23%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.40%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.39%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.38%
# Validation 7
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.37%
# Validation 8
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.21%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.40%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.32%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.37%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.26%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.21%
# Validation 5
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.36%
# Validation 7
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.41%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.39%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.18%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.40%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.32%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.33%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.34%
# Validation 1
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.15%
# Validation 3
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.34%
# Validation 4
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Validation 7
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.38%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Validation 1
# Fitting SVM
# Elapsed time 23 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.23%
# Validation 4
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.29%
# Validation 5
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.39%
# Validation 6
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.39%
# Validation 10
# Fitting SVM
# Elapsed time 24 seconds
#
# Accuracy of test set:: 0.36%
# Validation 1
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.39%
# Validation 8
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 26 seconds
#
# Accuracy of test set:: 0.35%
# Validation 10
# Fitting SVM
# Elapsed time 25 seconds
#
# Accuracy of test set:: 0.35%
# Fitting on 378 neurons
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 29 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 6
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.37%
# Validation 7
# Fitting SVM
# Elapsed time 31 seconds
#
# Accuracy of test set:: 0.42%
# Validation 8
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.31%
# Validation 9
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 30 seconds
#
# Accuracy of test set:: 0.38%
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR14,
                                                      taskdict=NR14_info['task_dict'],
                                                      taskcolors=NR14_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR14,
                                                         tracklength=NR14_info['tracklength'],
                                                         trackbins=NR14_info['trackbins'],
                                                         taskcolors=NR14_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR15

# %%
NR15_info = DataDetails.ExpAnimalDetails('NR15', classifier_type='SVM')
data_NR15 = runSVM(animalinfo=NR15_info, classifier_type='SVM')
# Out:
# Loading Data
# (6401, 1)
# (7595, 1)
# 1836
# Loading Behavior
# Good Running Data Frames: Task1, 6390
# Good Running Data Frames: Task2, 3690
# Data shapes: (5751, 434) (639, 434) (5751,) (639,)
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Performing 10-fold validation
# Validation 1
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# CV shape (639,)
# Validation 2
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# CV shape (639,)
# Validation 3
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# CV shape (639,)
# Validation 4
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# CV shape (639,)
# Validation 5
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# CV shape (639,)
# Validation 6
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.62%
# CV shape (639,)
# Validation 7
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# CV shape (639,)
# Validation 8
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# CV shape (639,)
# Validation 9
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# CV shape (639,)
# Validation 10
# (5751, 434) (5751,) (639, 434) (639,)
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# CV shape (639,)
# Fitting on 4 neurons
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.12%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.11%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.14%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.04%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.11%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.11%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.15%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.10%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 1
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 3
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 4
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.11%
# Validation 5
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Validation 6
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 7
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.09%
# Validation 8
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.07%
# Validation 9
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.06%
# Validation 10
# Fitting SVM
# Elapsed time 2 seconds
#
# Accuracy of test set:: 0.08%
# Fitting on 21 neurons
# Validation 1
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.25%
# Validation 4
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.14%
# Validation 6
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.22%
# Validation 7
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.28%
# Validation 8
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.24%
# Validation 10
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.26%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.14%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.17%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.19%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.17%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.22%
# Validation 1
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.14%
# Validation 3
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.16%
# Validation 4
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.29%
# Validation 5
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.16%
# Validation 7
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.23%
# Validation 8
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.21%
# Validation 1
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.21%
# Validation 6
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.19%
# Validation 7
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.24%
# Validation 8
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.22%
# Validation 9
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.18%
# Validation 1
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.05%
# Validation 2
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.21%
# Validation 3
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.31%
# Validation 5
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.30%
# Validation 7
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 3 seconds
#
# Accuracy of test set:: 0.25%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.16%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.20%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.16%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.13%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.19%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.20%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.18%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.10%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.11%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.17%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.06%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.08%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.07%
# Fitting on 43 neurons
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.18%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.36%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.29%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.24%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.40%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.30%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.40%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.34%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.38%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.36%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.32%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.32%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.17%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.21%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.15%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.15%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.25%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.19%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.27%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.21%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.25%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.27%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.22%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.24%
# Validation 1
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.40%
# Validation 4
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.38%
# Validation 5
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.35%
# Validation 7
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.49%
# Validation 8
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.37%
# Validation 9
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.39%
# Validation 10
# Fitting SVM
# Elapsed time 4 seconds
#
# Accuracy of test set:: 0.41%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.26%
# Validation 3
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.34%
# Validation 4
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.34%
# Validation 5
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.24%
# Validation 7
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.32%
# Validation 8
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.31%
# Validation 10
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.29%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.08%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.16%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.28%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.18%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.23%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.29%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.31%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.22%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.26%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.26%
# Fitting on 86 neurons
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.30%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.39%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.42%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.45%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.49%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.41%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.45%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.10%
# Validation 2
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.22%
# Validation 3
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 4
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.30%
# Validation 5
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.30%
# Validation 6
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.36%
# Validation 7
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.39%
# Validation 8
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.40%
# Validation 9
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.38%
# Validation 10
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.39%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.12%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.42%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.35%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.43%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.41%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.35%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.41%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.32%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.43%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.44%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.37%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.43%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.34%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.40%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.37%
# Validation 1
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.37%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.36%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.42%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.46%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.45%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.47%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.15%
# Validation 2
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.35%
# Validation 3
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.42%
# Validation 4
# Fitting SVM
# Elapsed time 6 seconds
# Accuracy of test set:: 0.41%
# Validation 5
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.41%
# Validation 6
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.47%
# Validation 8
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.52%
# Validation 9
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.50%
# Validation 10
# Fitting SVM
# Elapsed time 6 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 5 seconds
#
# Accuracy of test set:: 0.09%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.38%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.42%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.36%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.44%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.41%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.44%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.44%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.47%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.11%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.35%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.40%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.41%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Fitting on 217 neurons
# Validation 1
# Fitting SVM
# Elapsed time 10 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.43%
# Validation 3
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.57%
# Validation 5
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.53%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.51%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.56%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.53%
# Validation 9
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.61%
# Validation 10
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.56%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.45%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.55%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.53%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.58%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.52%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.61%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.22%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.43%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.51%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.53%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.53%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.52%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.61%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.48%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.55%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.51%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.13%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.38%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.55%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.54%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.55%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.38%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.56%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.59%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.56%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.57%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.58%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.49%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.57%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.55%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.16%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.38%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.59%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.58%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.55%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.53%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.53%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.59%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.56%
# Validation 1
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.48%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.59%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.56%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.62%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.58%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.41%
# Validation 3
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.53%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.56%
# Validation 5
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.55%
# Validation 6
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.50%
# Validation 7
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.62%
# Validation 8
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.50%
# Validation 9
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.57%
# Validation 10
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.54%
# Fitting on 347 neurons
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.43%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.65%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.60%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.63%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.65%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.61%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.47%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 5
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.61%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.56%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.66%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.55%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.46%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.60%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.61%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.59%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.17%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.44%
# Validation 3
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.64%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.59%
# Validation 6
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.57%
# Validation 8
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.56%
# Validation 9
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.62%
# Validation 10
# Fitting SVM
# Elapsed time 18 seconds
#
# Accuracy of test set:: 0.59%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.47%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.60%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.63%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.59%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.58%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.60%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.19%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.46%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.62%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.59%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.66%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.61%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.64%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.60%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.18%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.47%
# Validation 3
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 4
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.64%
# Validation 5
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.62%
# Validation 6
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.59%
# Validation 7
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.66%
# Validation 8
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.57%
# Validation 9
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.66%
# Validation 10
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.61%
# Validation 1
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.20%
# Validation 2
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.46%
# Validation 3
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.61%
# Validation 4
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.64%
# Validation 6
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.61%
# Validation 7
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.60%
# Validation 8
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.55%
# Validation 9
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.68%
# Validation 10
# Fitting SVM
# Elapsed time 16 seconds
#
# Accuracy of test set:: 0.64%
# Fitting on 434 neurons
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 1
# Fitting SVM
# Elapsed time 17 seconds
#
# Accuracy of test set:: 0.21%
# Validation 2
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.49%
# Validation 3
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# Validation 4
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 5
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.65%
# Validation 6
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.62%
# Validation 7
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.64%
# Validation 8
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.60%
# Validation 9
# Fitting SVM
# Elapsed time 21 seconds
#
# Accuracy of test set:: 0.67%
# Validation 10
# Fitting SVM
# Elapsed time 20 seconds
#
# Accuracy of test set:: 0.63%
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# (40, 40)
# Data shapes: (3321, 434) (369, 434) (3321,) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Performing 10-fold validation
# Validation 1
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# CV shape (369,)
# Validation 2
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# CV shape (369,)
# Validation 3
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# CV shape (369,)
# Validation 4
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# CV shape (369,)
# Validation 5
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# CV shape (369,)
# Validation 6
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# CV shape (369,)
# Validation 7
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# CV shape (369,)
# Validation 8
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# CV shape (369,)
# Validation 9
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# CV shape (369,)
# Validation 10
# (3321, 434) (3321,) (369, 434) (369,)
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# CV shape (369,)
# Fitting on 4 neurons
# Validation 1
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.04%
# Validation 2
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.07%
# Validation 3
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.04%
# Validation 4
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.02%
# Validation 5
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.02%
# Validation 6
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.03%
# Validation 7
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.05%
# Validation 8
# Fitting SVM
# Elapsed time 1 seconds
#
# Accuracy of test set:: 0.01%
# Validation 9
# Fitting SVM
# ...
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.37%
# Validation 1
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.28%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.43%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.19%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.23%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.22%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.21%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.21%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.31%
# Validation 1
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.32%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.24%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.19%
# Validation 5
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.27%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.18%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.21%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.21%
# Validation 10
# Fitting SVM
# Elapsed time 9 seconds
#
# Accuracy of test set:: 0.38%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.32%
# Validation 2
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.35%
# Validation 4
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.21%
# Validation 6
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.21%
# Validation 7
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.21%
# Validation 8
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.24%
# Validation 10
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.33%
# Validation 1
# Fitting SVM
# Elapsed time 7 seconds
#
# Accuracy of test set:: 0.27%
# Validation 2
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.28%
# Validation 3
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.25%
# Validation 4
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.26%
# Validation 5
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.26%
# Validation 6
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 8 seconds
#
# Accuracy of test set:: 0.36%
# Fitting on 347 neurons
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.39%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.37%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.27%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.34%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.26%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.24%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.41%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.34%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.38%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.23%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.37%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.35%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.35%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.26%
# Validation 8
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.42%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.39%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.36%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 6
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.27%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.35%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.43%
# Validation 1
# Fitting SVM
# Elapsed time 12 seconds
#
# Accuracy of test set:: 0.37%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.37%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.35%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.41%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.32%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.32%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.42%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.34%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.27%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 2
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 3
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.29%
# Validation 4
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.24%
# Validation 5
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.31%
# Validation 6
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.33%
# Validation 7
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.30%
# Validation 8
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.28%
# Validation 9
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.25%
# Validation 10
# Fitting SVM
# Elapsed time 11 seconds
#
# Accuracy of test set:: 0.41%
# Fitting on 434 neurons
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 13 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.40%
# Validation 1
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.36%
# Validation 2
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 3
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.30%
# Validation 4
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.28%
# Validation 5
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.33%
# Validation 6
# Fitting SVM
# Elapsed time 14 seconds
#
# Accuracy of test set:: 0.31%
# Validation 7
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.33%
# Validation 8
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.29%
# Validation 9
# Fitting SVM
# Elapsed time 15 seconds
#
# Accuracy of test set:: 0.28%
# Validation 10
# Fitting SVM

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR15,
                                                      taskdict=NR15_info['task_dict'],
                                                      taskcolors=NR15_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR15,
                                                         tracklength=NR15_info['tracklength'],
                                                         trackbins=NR15_info['trackbins'],
                                                         taskcolors=NR15_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR21

# %%
NR21_info = DataDetails.ExpAnimalDetails('NR21', classifier_type='SVM')
data_NR21 = runSVM(animalinfo=NR21_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR21,
                                                      taskdict=NR21_info['task_dict'],
                                                      taskcolors=NR21_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR21,
                                                         tracklength=NR21_info['tracklength'],
                                                         trackbins=NR21_info['trackbins'],
                                                         taskcolors=NR21_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR23

# %%
NR23_info = DataDetails.ExpAnimalDetails('NR23', classifier_type='SVM')
data_NR23 = runSVM(animalinfo=NR23_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR23,
                                                      taskdict=NR23_info['task_dict'],
                                                      taskcolors=NR23_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR23,
                                                         tracklength=NR23_info['tracklength'],
                                                         trackbins=NR23_info['trackbins'],
                                                         taskcolors=NR23_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## NR24

# %%
NR24_info = DataDetails.ExpAnimalDetails('NR24', classifier_type='SVM')
data_NR24 = runSVM(animalinfo=NR24_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_NR24,
                                                      taskdict=NR24_info['task_dict'],
                                                      taskcolors=NR24_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_NR24,
                                                         tracklength=NR24_info['tracklength'],
                                                         trackbins=NR24_info['trackbins'],
                                                         taskcolors=NR24_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## CFC4

# %%
CFC4_info = DataDetails.ExpAnimalDetails('CFC4', classifier_type='SVM')
data_CFC4 = runSVM(animalinfo=CFC4_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_CFC4,
                                                      taskdict=CFC4_info['task_dict'],
                                                      taskcolors=CFC4_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_CFC4,
                                                         tracklength=CFC4_info['tracklength'],
                                                         trackbins=CFC4_info['trackbins'],
                                                         taskcolors=CFC4_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## CFC16

# %%
CFC16_info = DataDetails.ExpAnimalDetails('CFC16', classifier_type='SVM')
data_CFC16 = runSVM(animalinfo=CFC16_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                        
                                                      modeldataframe=data_CFC16,
                                                      taskdict=CFC16_info['task_dict'],
                                                      taskcolors=CFC16_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_CFC16,
                                                         tracklength=CFC16_info['tracklength'],
                                                         trackbins=CFC16_info['trackbins'],
                                                         taskcolors=CFC16_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## CFC17

# %%
CFC17_info = DataDetails.ExpAnimalDetails('CFC17', classifier_type='SVM')
data_CFC17 = runSVM(animalinfo=CFC17_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_CFC17,
                                                      taskdict=CFC17_info['task_dict'],
                                                      taskcolors=CFC17_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_CFC17,
                                                         tracklength=CFC17_info['tracklength'],
                                                         trackbins=CFC17_info['trackbins'],
                                                         taskcolors=CFC17_info['task_colors'])
plt.tight_layout()

# %% [markdown]
# ## CFC19

# %%
CFC19_info = DataDetails.ExpAnimalDetails('CFC19', classifier_type='SVM')
data_CFC19 = runSVM(animalinfo=CFC19_info, classifier_type='SVM')

# %%
# Plot accuracy with numcells
fs, ax = plt.subplots(2, 1, figsize=(6, 5))
SVMValidationPlots.plot_decoderaccuracy_with_numcells(axis=ax[0],
                                                      modeldataframe=data_CFC19,
                                                      taskdict=CFC19_info['task_dict'],
                                                      taskcolors=CFC19_info['task_colors'])
SVMValidationPlots.plot_decoderaccuracy_with_tracklength(axis=ax[1],
                                                         modeldataframe=data_CFC19,
                                                         tracklength=CFC19_info['tracklength'],
                                                         trackbins=CFC19_info['trackbins'],
                                                         taskcolors=CFC19_info['task_colors'])
plt.tight_layout()
