# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from ParseandPlotNoReward_withGoodBehavior import GetData as gd
task_dict = {'Task1':'1 Fam Rew', 'Task2':'2 No Rew', 'Task2a':'2 No Rew No Lick', 'Task3':'3 Fam Rew', 'Task4':'4 Nov Rew'}

# %% [markdown]
# ## NR6

# %% [markdown]
# ### Input Parameters

# %%
FolderName = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/NR6/'
task_numframes = [20000, 20000, 15000, 15000]

# %%
A = gd(FolderName=FolderName, Task_NumFrames=task_numframes, TaskDict=task_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee25fa92e8e8> in <module>
# ----> 1 A = gd(FolderName=FolderName, Task_NumFrames=task_numframes, TaskDict=task_dict)
#
# NameError: name 'gd' is not defined

# %% [markdown]
# ### Plot Behavior parameters

# %%
A.plot_behavior()

# %%
A.plot_velocity()

# %%
A.plot_lick_per_lap()

# %% [markdown]
# ### Plot place cell parameters across tasks

# %%
A.plot_pf_params()

# %% [markdown]
# ### Plot cells that are place cells

# %%
A.plot_common_PF_heatmap()

# %% [markdown]
# ### Plot remapping

# %%
c = A.plot_remapping_withTaskA(TaskA='Task1')
c = A.plot_remapping_withTaskA(TaskA='Task3')

# %%
c = A.plot_remapping_withTaskA_splitbylickstop(TaskA='Task1')
c = A.plot_remapping_withTaskA_splitbylickstop(TaskA='Task3')

# %%
c = A.plot_remapping_withTaskA_splitbylickstop_normalizenumlaps(TaskA='Task1')
# Out:
# Task4 [5, 16, 9, 8, 7, 21, 19]
# Task1 [26, 4, 23, 40, 37, 35, 42]
# Task3 [8, 11, 10, 5, 15, 20, 17]
# Task2 [25, 12, 30, 14, 10, 11, 22]

# %%
x = A.significance_test_on_mapstability_bytask(TaskA='Task1', iterations=100)

# %% [markdown]
# ### COM of change in common place cells

# %%
A.location_of_commoncells_with_taskchange(TaskA='Task1')

# %% [markdown]
# ### Plot correlation of activity across trials

# %% [markdown]
# #### Place Cells

# %%
c = A.correlate_acivity_of_placecellbytask(TaskA='Task1')

# %% [markdown]
# #### All cells

# %%
c = A.correlate_acivity_of_allcellsbytask(TaskA='Task1')
